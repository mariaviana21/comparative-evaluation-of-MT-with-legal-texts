# %% [markdown]
# # Supervised Neural Machine Translation (Using JoeyNMT)

# %% [markdown]
# ## Note before beginning:
# ### - This notebook was provided for the subject of Machine Translation of the Master in Language Analysis and Procesing at UPV/EHU. In this notebook, we used two files (from Europarl: https://www.statmt.org/europarl/), one per language (EN-FR), where the lines in the files are corresponding translations.
#
# ### - We performed minimal changes to this in order to get SOME result for our own translation corpus.

# %% [markdown]
# ## Pre-process the data
#
# We already have a data set (from Europarl, as previously stated). The format in which we will process it here requires that
# 1. there are two files, one for each language (EN-FR)
# 2. the files are sentence-aligned, which means that each line should correspond to the same line in the other file.

# %%
# WE DOWNGRADE THE PYTHON VERSION BC JOEYNMT IS NOT WORKING ANYMORE WITH THE COMMANDS FOR INSTALLING IT THAT WE USED IN CLASS

# !sudo apt-get update -y
# !sudo apt-get install python3.8
from IPython.display import clear_output
clear_output()
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.8 1

# !sudo update-alternatives --config python3

# !python3 --version

# !sudo apt install python3-pip
# Out:
# There are 2 choices for the alternative python3 (providing /usr/bin/python3).
#
#   Selection    Path                 Priority   Status
# ------------------------------------------------------------
# * 0            /usr/bin/python3.10   2         auto mode
#   1            /usr/bin/python3.10   2         manual mode
#   2            /usr/bin/python3.8    1         manual mode
#
# Press <enter> to keep the current choice[*], or type selection number: 2
# update-alternatives: using /usr/bin/python3.8 to provide /usr/bin/python3 (python3) in manual mode
# Python 3.8.10
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   python-pip-whl python3-setuptools python3-wheel
# Suggested packages:
#   python-setuptools-doc
# The following NEW packages will be installed:
#   python-pip-whl python3-pip python3-setuptools python3-wheel
# 0 upgraded, 4 newly installed, 0 to remove and 25 not upgraded.
# Need to get 2,389 kB of archives.
# After this operation, 4,933 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 python-pip-whl all 20.0.2-5ubuntu1.8 [1,805 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-setuptools all 45.2.0-1ubuntu0.1 [330 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 python3-wheel all 0.34.2-1ubuntu0.1 [23.9 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 python3-pip all 20.0.2-5ubuntu1.8 [231 kB]
# Fetched 2,389 kB in 0s (7,332 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 4.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package python-pip-whl.
# (Reading database ... 122518 files and directories currently installed.)
# Preparing to unpack .../python-pip-whl_20.0.2-5ubuntu1.8_all.deb ...
# Unpacking python-pip-whl (20.0.2-5ubuntu1.8) ...
# Selecting previously unselected package python3-setuptools.
# Preparing to unpack .../python3-setuptools_45.2.0-1ubuntu0.1_all.deb ...
# Unpacking python3-setuptools (45.2.0-1ubuntu0.1) ...
# Selecting previously unselected package python3-wheel.
# Preparing to unpack .../python3-wheel_0.34.2-1ubuntu0.1_all.deb ...
# Unpacking python3-wheel (0.34.2-1ubuntu0.1) ...
# Selecting previously unselected package python3-pip.
# Preparing to unpack .../python3-pip_20.0.2-5ubuntu1.8_all.deb ...
# Unpacking python3-pip (20.0.2-5ubuntu1.8) ...
# Setting up python3-setuptools (45.2.0-1ubuntu0.1) ...
# Setting up python3-wheel (0.34.2-1ubuntu0.1) ...
# Setting up python-pip-whl (20.0.2-5ubuntu1.8) ...
# Setting up python3-pip (20.0.2-5ubuntu1.8) ...
# Processing triggers for man-db (2.9.1-1) ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# TODO: Set your source and target languages. Keep in mind, these traditionally use language codes as found here:
# These will also become the suffix's of all vocab and corpus files used throughout
import os
source_language = "en"
target_language = "fr" 
lc = False  # If True, lowercase the data.
seed = 42  # Random seed for shuffling.
tag = "baseline" # Give a unique name to your folder - this is to ensure you don't rewrite any models you've already submitted

os.environ["src"] = source_language # Sets them in bash as well, since we often use bash scripts
os.environ["tgt"] = target_language
os.environ["tag"] = tag

# This will save it to a folder in our gdrive instead!
# !mkdir -p "/content/drive/MyDrive/HAPLAPMaster/MachineTranslation/MT-project/$src-$tgt-$tag"
os.environ["gdrive_path"] = "/content/drive/MyDrive/HAPLAPMaster/MachineTranslation/MT-project/%s-%s-%s" % (source_language, target_language, tag)

# %%
# !echo "$gdrive_path"
# Out:
# /content/drive/MyDrive/HAPLAPMaster/MachineTranslation/MT-project/en-fr-baseline

# %%
# Install opus-tools
! pip install opustools-pkg
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting opustools-pkg
#   Downloading opustools_pkg-0.0.52-py3-none-any.whl (80 kB)
#      |████████████████████████████████| 80 kB 3.2 MB/s
# Installing collected packages: opustools-pkg
# Successfully installed opustools-pkg-0.0.52

# %%
# TODO: specify the file paths here 
corpora_prefix = "/content/drive/MyDrive/HAPLAPMaster/MachineTranslation/MT-project/en-fr/europarl-v7.fr-en"
source_file = corpora_prefix+"."+source_language
target_file = corpora_prefix+"."+target_language

! wget https://raw.githubusercontent.com/moses-smt/mosesdecoder/master/scripts/training/clean-corpus-n.perl
! perl clean-corpus-n.perl $corpora_prefix $source_language $target_language $corpora_prefix".clean" 1 75

source_file = corpora_prefix+".clean."+source_language
target_file = corpora_prefix+".clean."+target_language

# They should both have the same length.
! wc -l "$source_file"
! wc -l "$target_file"
# Out:
# --2023-05-06 12:25:56--  https://raw.githubusercontent.com/moses-smt/mosesdecoder/master/scripts/training/clean-corpus-n.perl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4257 (4.2K) [text/plain]
# Saving to: ‘clean-corpus-n.perl’
#
# clean-corpus-n.perl 100%[===================>]   4.16K  --.-KB/s    in 0s
#
# 2023-05-06 12:25:57 (41.7 MB/s) - ‘clean-corpus-n.perl’ saved [4257/4257]
#
# clean-corpus.perl: processing /content/drive/MyDrive/HAPLAPMaster/MachineTranslation/MT-project/en-fr/europarl-v7.fr-en.en & .fr to /content/drive/MyDrive/HAPLAPMaster/MachineTranslation/MT-project/en-fr/europarl-v7.fr-en.clean, cutoff 1-75, ratio 9
# ..........(100000)..........(200000)..........(300000)..........(400000)..........(500000)..........(600000)..........(700000)..........(800000)..........(900000)..........(1000000)..........(1100000)..........(1200000)..........(1300000)..........(1400000)..........(1500000)..........(1600000)..........(1700000)..........(1800000)..........(1900000)..........(2000000)
# Input sentences: 2007723  Output sentences:  1977578
# 1977578 /content/drive/MyDrive/HAPLAPMaster/MachineTranslation/MT-project/en-fr/europarl-v7.fr-en.clean.en
# 1977578 /content/drive/MyDrive/HAPLAPMaster/MachineTranslation/MT-project/en-fr/europarl-v7.fr-en.clean.fr

# %%
# TODO: Pre-processing! (OPTIONAL)

# If your data contains weird symbols or the like, you might want to do some cleaning and normalization.
# We don't have the code in the notebook for that, but you can use sacremoses "normalize" for example for normalization punctuation: https://github.com/alvations/sacremoses.

# We apply tokenization to separate punctuation marks from the actual words, split words at hyphens etc.
# If you're data is already tokenized, that's great! Skip this cell.
# Otherwise we can use sacremoses to do the tokenization for us. 
# We need the data to be tokenized such that it matches the global test set.

! pip install sacremoses

tok_source_file = source_file+".tok"
tok_target_file = target_file+".tok"

# Tokenize the source
! sacremoses -l "$source_language" tokenize < "$source_file" > "$tok_source_file"
# Tokenize the target
! sacremoses -l "$target_language" tokenize < "$target_file" > "$tok_target_file"

# Let's take a look what tokenization did to the text.
! tail "$source_file"*
! tail "$target_file"*
! wc -l "$target_file"* "$source_file"*

# Change the pointers to our files such that we continue to work with the tokenized data.
source_file = tok_source_file
target_file = tok_target_file
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sacremoses
#   Downloading sacremoses-0.0.53.tar.gz (880 kB)
#      |████████████████████████████████| 880 kB 4.4 MB/s
# Collecting click
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 5.9 MB/s
# Collecting joblib
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      |████████████████████████████████| 297 kB 82.4 MB/s
# Collecting regex
#   Downloading regex-2023.5.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (771 kB)
#      |████████████████████████████████| 771 kB 60.7 MB/s
# Collecting six
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting tqdm
#   Downloading tqdm-4.65.0-py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 5.8 MB/s
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.53-py3-none-any.whl size=895255 sha256=f3ab53459338296d6973b85bab153713c817a13970f6194ac0a48e8afed7391a
#   Stored in directory: /root/.cache/pip/wheels/82/ab/9b/c15899bf659ba74f623ac776e861cf2eb8608c1825ddec66a4
# Successfully built sacremoses
# Installing collected packages: click, joblib, regex, six, tqdm, sacremoses
# Successfully installed click-8.1.3 joblib-1.2.0 regex-2023.5.5 sacremoses-0.0.53 six-1.16.0 tqdm-4.65.0
# ==> /content/drive/MyDrive/HAPLAPMaster/MachineTranslation/MT-project/en-fr/europarl-v7.fr-en.clean.en <==
# Having said that, Parliament has reached the end of the agenda.
# The Minutes of the present sitting will be subject to Parliament' s approval at the beginning of the next part-session.
# Mr Manders has the floor for a procedural motion.
# Mr President, I would like to take this opportunity to wish you, the Bureau and all Members, a good transition into the new year.
# Ladies and gentlemen, before you leave me alone, I would like on behalf of the Bureau, once again, to thank all the Members, all the services, officials, assistants and other co-workers and, if you will allow me - although all the co-workers work for us - perhaps a special mention should go to the language services which help us to understand each other here.
# I would also like, although they are absent, to mention the Commission and the Council.
# I am not going to re-open the 'Millennium or not the Millennium' debate, but I am going to wish all of you, and by extension, all the citizens of Europe which we represent, a happy year 2000.
# Adjournment of the session
# I declare the session of the European Parliament adjourned.
# (The sitting was closed at 10.50 a.m.)
#
# ==> /content/drive/MyDrive/HAPLAPMaster/MachineTranslation/MT-project/en-fr/europarl-v7.fr-en.clean.en.tok <==
# Having said that , Parliament has reached the end of the agenda .
# The Minutes of the present sitting will be subject to Parliament &apos; s approval at the beginning of the next part-session .
# Mr Manders has the floor for a procedural motion .
# Mr President , I would like to take this opportunity to wish you , the Bureau and all Members , a good transition into the new year .
# Ladies and gentlemen , before you leave me alone , I would like on behalf of the Bureau , once again , to thank all the Members , all the services , officials , assistants and other co-workers and , if you will allow me - although all the co-workers work for us - perhaps a special mention should go to the language services which help us to understand each other here .
# I would also like , although they are absent , to mention the Commission and the Council .
# I am not going to re-open the &apos; Millennium or not the Millennium &apos; debate , but I am going to wish all of you , and by extension , all the citizens of Europe which we represent , a happy year 2000 .
# Adjournment of the session
# I declare the session of the European Parliament adjourned .
# ( The sitting was closed at 10.50 a.m. )
# ==> /content/drive/MyDrive/HAPLAPMaster/MachineTranslation/MT-project/en-fr/europarl-v7.fr-en.clean.fr <==
# Ceci étant dit, Mesdames et Messieurs les Députés, il n'y a plus de point à l'ordre du jour.
# Le procès-verbal de la présente séance sera soumis à l'adoption du Parlement au début de la prochaine séance.
# Je donne la parole à M. Manders pour une motion de procédure.
# Monsieur le Président, je voudrais profiter de l'occasion pour vous souhaiter, ainsi qu'au Bureau et à tous les collègues, une bonne transition vers la nouvelle année.
# Mesdames et Messieurs les Députés, avant votre départ, je tiens, au nom du Bureau, à remercier tous les députés, tous les services, tous les fonctionnaires, les assistants et autres collaborateurs et, si vous me le permettez, bien que tous les collaborateurs travaillent pour nous, j'aimerais peut-être remercier spécialement les services linguistiques qui nous aident à nous comprendre.
# Je me permettrai même, bien qu'ils soient absents, de remercier la Commission et le Conseil.
# Je ne rouvrirai pas le débat sur le millénaire, mais je vous souhaite à toutes et à tous et, par-là même, à tous les citoyens européens que nous représentons, une heureuse année 2000.
# Interruption de la session
# Je déclare interrompue la session du Parlement européen.
# (La séance est levée à 10h50)
#
# ==> /content/drive/MyDrive/HAPLAPMaster/MachineTranslation/MT-project/en-fr/europarl-v7.fr-en.clean.fr.tok <==
# Ceci étant dit , Mesdames et Messieurs les Députés , il n&apos; y a plus de point à l&apos; ordre du jour .
# Le procès-verbal de la présente séance sera soumis à l&apos; adoption du Parlement au début de la prochaine séance .
# Je donne la parole à M. Manders pour une motion de procédure .
# Monsieur le Président , je voudrais profiter de l&apos; occasion pour vous souhaiter , ainsi qu&apos; au Bureau et à tous les collègues , une bonne transition vers la nouvelle année .
# Mesdames et Messieurs les Députés , avant votre départ , je tiens , au nom du Bureau , à remercier tous les députés , tous les services , tous les fonctionnaires , les assistants et autres collaborateurs et , si vous me le permettez , bien que tous les collaborateurs travaillent pour nous , j&apos; aimerais peut-être remercier spécialement les services linguistiques qui nous aident à nous comprendre .
# Je me permettrai même , bien qu&apos; ils soient absents , de remercier la Commission et le Conseil .
# Je ne rouvrirai pas le débat sur le millénaire , mais je vous souhaite à toutes et à tous et , par-là même , à tous les citoyens européens que nous représentons , une heureuse année 2000 .
# Interruption de la session
# Je déclare interrompue la session du Parlement européen .
# ( La séance est levée à 10h50 )
#    1977578 /content/drive/MyDrive/HAPLAPMaster/MachineTranslation/MT-project/en-fr/europarl-v7.fr-en.clean.fr
#    1977578 /content/drive/MyDrive/HAPLAPMaster/MachineTranslation/MT-project/en-fr/europarl-v7.fr-en.clean.fr.tok
#    1977578 /content/drive/MyDrive/HAPLAPMaster/MachineTranslation/MT-project/en-fr/europarl-v7.fr-en.clean.en
#    1977578 /content/drive/MyDrive/HAPLAPMaster/MachineTranslation/MT-project/en-fr/europarl-v7.fr-en.clean.en.tok
#    7910312 total

# %%
# SKIPPING THIS PART BC WE HAVE OUR OWN TEST SET
# Download FLORES test set for this language pair (https://github.com/facebookresearch/flores).
# TODO: update languages codes as used in FLORES testset (eng instead of en)
#os.environ["ltrg"] = "fra"
#os.environ["lsrc"] = "eng"
#os.environ["trg"] = target_language 
#os.environ["src"] = source_language 

#! rm -fr flores101_dataset*
#! wget https://dl.fbaipublicfiles.com/flores101/dataset/flores101_dataset.tar.gz
#! tar -xvzf flores101_dataset.tar.gz

#! mv flores101_dataset/devtest/$lsrc.devtest test.$src
#! mv flores101_dataset/devtest/$ltrg.devtest test.$trg

# If this fails it means that there is NO test set for your language. 
# Anayway, we will split your corpora on train/dev/test partitions

# %%
# Using our own test set downloaded from the ECHR website: https://hudoc.echr.coe.int/eng#{%22documentcollectionid2%22:[%22GRANDCHAMBER%22,%22CHAMBER%22]}
# CLEANING TEST SET
# TODO: specify the file paths here 
test_prefix = "/content/drive/MyDrive/HAPLAPMaster/MachineTranslation/MT-project/en-fr/NMT-test"
source_test = test_prefix+"."+source_language
target_test = test_prefix+"."+target_language

! wget https://raw.githubusercontent.com/moses-smt/mosesdecoder/master/scripts/training/clean-corpus-n.perl
! perl clean-corpus-n.perl $test_prefix $source_language $target_language $test_prefix".clean" 1 75

source_test = test_prefix+".clean."+source_language
target_test = test_prefix+".clean."+target_language

# They should both have the same length.
! wc -l "$source_test"
! wc -l "$target_test"
# Out:
# --2023-05-06 12:48:38--  https://raw.githubusercontent.com/moses-smt/mosesdecoder/master/scripts/training/clean-corpus-n.perl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4257 (4.2K) [text/plain]
# Saving to: ‘clean-corpus-n.perl.1’
#
# clean-corpus-n.perl 100%[===================>]   4.16K  --.-KB/s    in 0s
#
# 2023-05-06 12:48:38 (57.9 MB/s) - ‘clean-corpus-n.perl.1’ saved [4257/4257]
#
# clean-corpus.perl: processing /content/drive/MyDrive/HAPLAPMaster/MachineTranslation/MT-project/en-fr/NMT-test.en & .fr to /content/drive/MyDrive/HAPLAPMaster/MachineTranslation/MT-project/en-fr/NMT-test.clean, cutoff 1-75, ratio 9
#
# Input sentences: 340  Output sentences:  330
# 330 /content/drive/MyDrive/HAPLAPMaster/MachineTranslation/MT-project/en-fr/NMT-test.clean.en
# 330 /content/drive/MyDrive/HAPLAPMaster/MachineTranslation/MT-project/en-fr/NMT-test.clean.fr

# %%
# TOKENIZING TEST SET
echr_tok_test_en = source_test+".tok"
echr_tok_test_fr = target_test+".tok"

# Tokenize the source
! sacremoses -l "$source_language" tokenize < "$source_test" > "$echr_tok_test_en"
# Tokenize the target
! sacremoses -l "$target_language" tokenize < "$target_test" > "$echr_tok_test_fr"

# Let's take a look what tokenization did to the text.
! tail "$source_test"*
! tail "$target_test"*
! wc -l "$target_test"* "$source_test"*

# Change the pointers to our files such that we continue to work with the tokenized data.
source_test = echr_tok_test_en
target_test = echr_tok_test_fr
# Out:
# ==> /content/drive/MyDrive/HAPLAPMaster/MachineTranslation/MT-project/en-fr/NMT-test.clean.en <==
# I offer no evidence.
# Verdicts must follow.”
# The applicant was duly acquitted.
# On his counsel's application for a defendant's costs order, the judge refused to make an order and stated:
# “That order will be refused.
# There is clear evidence on the court papers.
# The Crown have taken the view that they are not going to compel this witness although there is compelling evidence in respect of those matters.
# It is a discretion which I am afraid I am not going to exercise in your favour.”
# The applicant's attempted appeal was dismissed on 14 November 2003 as “to be appealable as a sentence, the order must be contingent upon conviction.
# As the defendant's costs order only arises when a prosecution is unsuccessful, it cannot be a sentence and cannot be appealed at the Court of Appeal Criminal Division”.
#
# ==> /content/drive/MyDrive/HAPLAPMaster/MachineTranslation/MT-project/en-fr/NMT-test.clean.en.tok <==
# I offer no evidence .
# Verdicts must follow . ”
# The applicant was duly acquitted .
# On his counsel &apos;s application for a defendant &apos;s costs order , the judge refused to make an order and stated :
# “ That order will be refused .
# There is clear evidence on the court papers .
# The Crown have taken the view that they are not going to compel this witness although there is compelling evidence in respect of those matters .
# It is a discretion which I am afraid I am not going to exercise in your favour . ”
# The applicant &apos;s attempted appeal was dismissed on 14 November 2003 as “ to be appealable as a sentence , the order must be contingent upon conviction .
# As the defendant &apos;s costs order only arises when a prosecution is unsuccessful , it cannot be a sentence and cannot be appealed at the Court of Appeal Criminal Division ” .
# ==> /content/drive/MyDrive/HAPLAPMaster/MachineTranslation/MT-project/en-fr/NMT-test.clean.fr <==
# Je n'ai aucun élément de preuve à présenter.
# Il y a lieu de rendre le verdict. »
# Le requérant fut dûment acquitté.
# Son avocat ayant demandé que les dépens de son client lui soient remboursés, le juge refusa en déclarant :
# « Pareil remboursement est refusé.
# Il y a des éléments de preuve clairs dans les pièces du dossier.
# Le ministère public est d'avis qu'il n'entend pas contraindre cette personne à témoigner bien qu'il existe des éléments de preuve convaincants sur ces questions.
# Il s'agit d'un pouvoir discrétionnaire que, je le crains, je n'exercerai pas en votre faveur. »
# Le requérant interjeta appel et il fut débouté le 14 novembre 2003 avec l'explication suivante : « Pour pouvoir être contestée en appel en tant que sentence, la décision doit faire suite à une condamnation.
# Or la décision de rembourser les dépens du défendeur n'étant prise que lorsque l'action publique n'a pas abouti, elle ne constitue pas une sentence et ne peut donc faire l'objet d'un recours devant la chambre criminelle de la Cour d'appel. »
#
# ==> /content/drive/MyDrive/HAPLAPMaster/MachineTranslation/MT-project/en-fr/NMT-test.clean.fr.tok <==
# Je n&apos; ai aucun élément de preuve à présenter .
# Il y a lieu de rendre le verdict . »
# Le requérant fut dûment acquitté .
# Son avocat ayant demandé que les dépens de son client lui soient remboursés , le juge refusa en déclarant :
# « Pareil remboursement est refusé .
# Il y a des éléments de preuve clairs dans les pièces du dossier .
# Le ministère public est d&apos; avis qu&apos; il n&apos; entend pas contraindre cette personne à témoigner bien qu&apos; il existe des éléments de preuve convaincants sur ces questions .
# Il s&apos; agit d&apos; un pouvoir discrétionnaire que , je le crains , je n&apos; exercerai pas en votre faveur . »
# Le requérant interjeta appel et il fut débouté le 14 novembre 2003 avec l&apos; explication suivante : « Pour pouvoir être contestée en appel en tant que sentence , la décision doit faire suite à une condamnation .
# Or la décision de rembourser les dépens du défendeur n&apos; étant prise que lorsque l&apos; action publique n&apos; a pas abouti , elle ne constitue pas une sentence et ne peut donc faire l&apos; objet d&apos; un recours devant la chambre criminelle de la Cour d&apos; appel . »
#    330 /content/drive/MyDrive/HAPLAPMaster/MachineTranslation/MT-project/en-fr/NMT-test.clean.fr
#    330 /content/drive/MyDrive/HAPLAPMaster/MachineTranslation/MT-project/en-fr/NMT-test.clean.fr.tok
#    330 /content/drive/MyDrive/HAPLAPMaster/MachineTranslation/MT-project/en-fr/NMT-test.clean.en
#    330 /content/drive/MyDrive/HAPLAPMaster/MachineTranslation/MT-project/en-fr/NMT-test.clean.en.tok
#   1320 total

# %%
# Read the test data to filter from train and dev splits.
# Store english portion in set for quick filtering checks.
en_test_sents = set()
filter_test_sents = echr_tok_test_en
j = 0
with open(filter_test_sents) as f:
  for line in f:
    en_test_sents.add(line.strip())
    j += 1
print('Loaded {} global test sentences to filter from the training/dev data.'.format(j))
# Out:
# Loaded 330 global test sentences to filter from the training/dev data.

# %%
import pandas as pd

source = []
target = []
skip_lines = []  # Collect the line numbers of the source portion to skip the same lines for the target portion.
with open(source_file) as f:
    for i, line in enumerate(f):
        # Skip sentences that are contained in the test set.
        if line.strip() not in en_test_sents:
            source.append(line.strip())
        else:
            skip_lines.append(i)             
with open(target_file) as f:
    for j, line in enumerate(f):
        # Only add to corpus if corresponding source was not skipped.
        if j not in skip_lines:
            target.append(line.strip())
    
print('Loaded data and skipped {}/{} lines since contained in test set.'.format(len(skip_lines), i))
    
df = pd.DataFrame(zip(source, target), columns=['source_sentence', 'target_sentence'])
df.tail(3)
# Out:
# Loaded data and skipped 0/1977577 lines since contained in test set.
#                                            source_sentence  \
# 1977575                         Adjournment of the session
# 1977576  I declare the session of the European Parliame...
# 1977577           ( The sitting was closed at 10.50 a.m. )
#
#                                            target_sentence
# 1977575                         Interruption de la session
# 1977576  Je déclare interrompue la session du Parlement...
# 1977577                    ( La séance est levée à 10h50 )

# %%
# TEST TO DF

source = []
target = []
#skip_lines = []  # Collect the line numbers of the source portion to skip the same lines for the target portion.
with open(source_test) as f:
    for i, line in enumerate(f):
        # Skip sentences that are contained in the test set.
        #if line.strip() not in en_test_sents:
        source.append(line.strip())
        #else:
            #skip_lines.append(i)             
with open(target_test) as f:
    for j, line in enumerate(f):
        # Only add to corpus if corresponding source was not skipped.
        #if j not in skip_lines:
        target.append(line.strip())
    
#print('Loaded data and skipped {}/{} lines since contained in test set.'.format(len(skip_lines), i))
    
df_test = pd.DataFrame(zip(source, target), columns=['source_sentence', 'target_sentence'])
df_test.tail(3)
# Out:
#                                        source_sentence  \
# 327  It is a discretion which I am afraid I am not ...
# 328  The applicant &apos;s attempted appeal was dis...
# 329  As the defendant &apos;s costs order only aris...
#
#                                        target_sentence
# 327  Il s&apos; agit d&apos; un pouvoir discrétionn...
# 328  Le requérant interjeta appel et il fut débouté...
# 329  Or la décision de rembourser les dépens du déf...

# %% [markdown]
# ## Pre-processing and export
#
# It is generally a good idea to remove duplicate translations and conflicting translations from the corpus. In practice, these public corpora include some number of these that need to be cleaned.
#
# In addition we will split our data into dev/test/train and export to the filesystem.

# %%
# IN THIS NOTEBOOK WE ARE NOT DROPPING DUPLICATES BC FUZZYWUZZY IS NOT WORKING WITH THE PYTHON VERSION THAT WE ARE USING

# drop duplicate translations
df_pp=df
df_pp.drop_duplicates()

# drop conflicting translations
df_pp.drop_duplicates(subset='source_sentence', inplace=True)
df_pp.drop_duplicates(subset='target_sentence', inplace=True)

# Shuffle the data to remove bias in dev set selection.
df_pp = df_pp.sample(frac=1, random_state=seed).reset_index(drop=True)

# %%
# This section does the split between train/dev(/test) for the parallel corpora then saves them as separate files
# We use 1000 dev test and the given test set.
import csv

# TODO: if your corpus is smaller than 1000, reduce this number. With a corpus that small you might not obtain good results with NMT though :/
# Do the split between dev/train and create parallel corpora
num_dev_patterns = 1000

# Optional: lower case the corpora - this will make it easier to generalize, but without proper casing.
if lc:  # making lowercasing optional
    df_pp["source_sentence"] = df_pp["source_sentence"].str.lower()
    df_pp["target_sentence"] = df_pp["target_sentence"].str.lower()

# TODO: change to True if doesn't exist a FLORES test sets for your language pairs
createTestset = True
if createTestset:
  #test = df_pp.tail(num_dev_patterns)
  test = df_test
  with open("test."+source_language, "w") as src_file, open("test."+target_language, "w") as trg_file:
    for index, row in test.iterrows():
      src_file.write(row["source_sentence"]+"\n")
      trg_file.write(row["target_sentence"]+"\n")
  #dev = df_pp.tail(2*num_dev_patterns).head(num_dev_patterns)
  #stripped = df_pp.drop(df_pp.tail(2*num_dev_patterns).index)
  dev = df_pp.tail(num_dev_patterns)
  stripped = df_pp.drop(df_pp.tail(num_dev_patterns).index)
else:
  dev = df_pp.tail(num_dev_patterns)
  stripped = df_pp.drop(df_pp.tail(num_dev_patterns).index)

with open("train."+source_language, "w") as src_file, open("train."+target_language, "w") as trg_file:
  for index, row in stripped.iterrows():
    src_file.write(row["source_sentence"]+"\n")
    trg_file.write(row["target_sentence"]+"\n")
    
with open("dev."+source_language, "w") as src_file, open("dev."+target_language, "w") as trg_file:
  for index, row in dev.iterrows():
    src_file.write(row["source_sentence"]+"\n")
    trg_file.write(row["target_sentence"]+"\n")

stripped[["source_sentence"]].to_csv("train."+source_language, header=False, index=False)  
stripped[["target_sentence"]].to_csv("train."+target_language, header=False, index=False)  

dev[["source_sentence"]].to_csv("dev."+source_language, header=False, index=False)
dev[["target_sentence"]].to_csv("dev."+target_language, header=False, index=False)


# TODO: Doublecheck the format below. There should be no extra quotation marks or weird characters. It should also not be empty.
! head train.*
! head dev.*
! wc {train,dev,test}.*
# Out:
# ==> train.en <==
# We can therefore conduct this debate again with those who really know the ropes and who do not believe it is enough simply to impose standards .
# "The European Parliament should work hard to make an ambitious , Europeanist response worthy of our citizens ."
# "The compromise at first reading , though challenging democratically , is a sensible solution for an update such as this one , and reaching it was in itself an environmental accomplishment ."
# "It is at this point that I will address Mr Balkenende and say that it could have been much better than it is if your government , Mr Balkenende , had acted to resolve an issue about which we have had very lively discussions and will continue to do so ."
# "First , the scope and structure of the programme ."
# The new legislation should affect all the communications infrastructures and related services by means of recommendations and codes of conduct and other vehicles .
# Yet today this country is preparing to host the World Conference Against Racism .
# "We need to open up the European energy , transport and financial services markets and improve the regulatory framework and consumer protection ."
# "This led to 42 new amendments , which were signed by most of the groups ."
# This would indeed be an important contribution to the defence of European interests and to the strengthening of the European prospects of the countries in the area .
#
# ==> train.fr <==
# L ’ adoption de l ’ amendement portant sur cette disposition est capitale .
# Le Parlement européen doit travailler dur pour apporter une réponse européiste ambitieuse digne de nos concitoyens .
# "Un compromis en première lecture , véritable défi démocratique , est une solution raisonnable pour une révision de ce type . Y être parvenu est , en soi , une prouesse environnementale ."
# "Je m ’ adresserai en ce sens à M. Balkenende pour lui dire que la Commission aurait pu être encore meilleure si votre gouvernement , Monsieur Balkenende , avait voulu résoudre un problème au sujet duquel nous avons connu - et nous connaîtrons encore - des discussions très animées ."
# "Premièrement , je parlerai de l&apos; étendue et de la structure du programme ."
# "La nouvelle législation devrait concerner toutes les infrastructures de communication et les services afférents , au moyen notamment de recommandations et de codes de conduite ."
# Aujourd&apos; hui pourtant ce pays s&apos; apprête à accueillir la Conférence mondiale contre le racisme .
# "Nous devons ouvrir les marchés européens de l&apos; énergie , des transports et des services financiers , améliorer le cadre réglementaire et la protection des consommateurs ."
# "C&apos; est pourquoi 42 amendements ont été déposés , amendements signés par la plupart des groupes ."
# Cette stratégie contribuerait en effet de façon non négligeable à la défense des intérêts européens et au renforcement des perspectives européennes offertes aux pays de la région .
# ==> dev.en <==
# The regions need to be given room to invest in their infrastructure and people according to their own priorities .
# I think we should have a rule that we should know at least two hours in advance who will take the floor in the one-minute speeches .
# "The President allocated me two minutes and thirty seconds , and I would like to make full use of them ."
# It is therefore right to recommend that greater regulation be imposed on European football and that this should be connected with European law and the dynamics of the internal market .
# "It may be better to carry out thorough improvements to that which is already in existence than to wait for the new one , as time is passing and people are becoming impatient ."
# We are all aware that the European integration process has numerous advantages for Serbia .
# "For some time , the Commission has recognised the link between capital flight and corruption and criminality in Russia and we also understand the cumulative threat these conditions pose to the country &apos; s transition to a democratic system and a market economy governed by the rule of law ."
# "Both in the multi-annual programme on consumer protection and in the resolution and the debate further to the withdrawal from the market of unsafe , mainly Chinese toys , we have made passionate pleas for the protection of the smallest and most vulnerable consumers , namely children , to be placed high on the agenda ."
# The murder of Mrs Abiola is simply the last and most serious incident in a long series of violations of democracy and human rights in Nigeria .
# So I am going to admit that when something goes wrong in this Parliament it is because the Presidents make a mess of the good work done by the Presidency &apos;s officers .
#
# ==> dev.fr <==
# Les régions doivent avoir la possibilité d&apos; investir dans leur infrastructure et leurs citoyens en fonction des priorités qui leur sont propres .
# Je pense qu&apos; il devrait y avoir une règle pour que nous sachions au moins deux heures à l&apos; avance qui s&apos; exprimera dans les interventions d&apos; une minute .
# Le président m ’ a accordé deux minutes et trente secondes et je voudrais les utiliser pleinement .
# Il est donc normal de recommander que des réglementations plus strictes soient imposées au football européen et que celles-ci soient liées par la législation européenne et la dynamique du marché intérieur .
# "Il serait peut-être plus avisé de procéder à des améliorations en profondeur du règlement déjà existant que d&apos; attendre le nouveau , étant donné que le temps passe et que les citoyens se font impatients ."
# Nous savons tous que le processus d&apos; intégration présente de nombreux avantages pour la Serbie .
# Cela fait un certain temps déjà que la Commission reconnaît le lien entre la fuite des capitaux et la corruption et la criminalité en Russie ; nous admettons aussi la menace cumulée que ces différents facteurs font peser sur le processus de transition de ce pays vers un système démocratique et une économie de marché régis par l&apos; État de droit .
# "Tant dans le programme pluriannuel de protection des consommateurs que dans la résolution et le débat ultérieur sur le retrait du marché des jouets dangereux , principalement chinois , nous avons passionnément plaidé pour que la protection des consommateurs les plus jeunes et les plus vulnérables , à savoir les enfants , soit inscrite en première place sur l&apos; agenda ."
# Celui de Mme Abiola n&apos; est que le dernier et très grave épisode d&apos; une longue série de violations de la démocratie et des droits de l&apos; homme au Nigeria .
# "Donc , je dois vous dire que lorsque quelque chose ne fonctionne pas bien dans cette Assemblée , c&apos; est parce que les présidents gâchent le bon travail des fonctionnaires de la présidence ."
#   1918119  52896185 294879145 train.en
#   1918119  58742632 353973931 train.fr
#      1000     27658    154077 dev.en
#      1000     30652    184567 dev.fr
#       330      8526     45235 test.en
#       330      9396     50616 test.fr
#   3838898 111715049 649287571 total

# %% [markdown]
# ---
#
#
# ## Installation of JoeyNMT
#
# JoeyNMT is a simple, minimalist NMT package which is useful for learning and teaching. Check out the documentation for JoeyNMT [here](https://joeynmt.readthedocs.io)

# %%
! pip install -e git+https://github.com/joeynmt/joeynmt.git@1.5#egg=joeynmt
! rm -fr joeynmt
! git clone https://github.com/joeynmt/joeynmt.git --branch 1.5 --single-branch
! pip install torch==1.10.1+cu102 torchtext==0.11.1 -f https://download.pytorch.org/whl/torch_stable.html
! pip install setuptools==59.5.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining joeynmt from git+https://github.com/joeynmt/joeynmt.git@1.5#egg=joeynmt
#   Cloning https://github.com/joeynmt/joeynmt.git (to revision 1.5) to ./src/joeynmt
#   Running command git clone -q https://github.com/joeynmt/joeynmt.git /content/src/joeynmt
#   Running command git checkout -q 092c504cb3d7b25b91cc37af4fbfe55af4faf64f
# Collecting future
#   Downloading future-0.18.3.tar.gz (840 kB)
#      |████████████████████████████████| 840 kB 4.4 MB/s
# Collecting matplotlib
#   Downloading matplotlib-3.7.1-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.2 MB)
#      |████████████████████████████████| 9.2 MB 64.3 MB/s
# Collecting numpy>=1.19.5
#   Downloading numpy-1.24.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      |████████████████████████████████| 17.3 MB 70.7 MB/s
# Collecting pillow
#   Downloading Pillow-9.5.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 77.8 MB/s
# Collecting pylint>=2.9.6
#   Downloading pylint-2.17.3-py3-none-any.whl (536 kB)
#      |████████████████████████████████| 536 kB 81.0 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (701 kB)
#      |████████████████████████████████| 701 kB 61.9 MB/s
# Collecting sacrebleu>=2.0.0
#   Downloading sacrebleu-2.3.1-py3-none-any.whl (118 kB)
#      |████████████████████████████████| 118 kB 84.6 MB/s
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      |████████████████████████████████| 293 kB 84.6 MB/s
# Requirement already satisfied: setuptools>=41.0.0 in /usr/lib/python3/dist-packages (from joeynmt) (45.2.0)
# Requirement already satisfied: six>=1.12 in /usr/local/lib/python3.8/dist-packages (from joeynmt) (1.16.0)
# Collecting subword-nmt
#   Downloading subword_nmt-0.3.8-py3-none-any.whl (27 kB)
# Collecting tensorboard>=1.15
#   Downloading tensorboard-2.13.0-py3-none-any.whl (5.6 MB)
#      |████████████████████████████████| 5.6 MB 76.6 MB/s
# Collecting torch>=1.9.0
#   Downloading torch-2.0.0-cp38-cp38-manylinux1_x86_64.whl (619.9 MB)
#      |████████████████████████████████| 619.9 MB 27 kB/s
# Collecting torchtext>=0.10.0
#   Downloading torchtext-0.15.1-cp38-cp38-manylinux1_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 51.4 MB/s
# Collecting wrapt==1.11.1
#   Downloading wrapt-1.11.1.tar.gz (27 kB)
# Collecting importlib-resources>=3.2.0; python_version < "3.10"
#   Downloading importlib_resources-5.12.0-py3-none-any.whl (36 kB)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.7-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (300 kB)
#      |████████████████████████████████| 300 kB 61.3 MB/s
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 7.8 MB/s
# Collecting python-dateutil>=2.7
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
#      |████████████████████████████████| 247 kB 72.7 MB/s
# Collecting packaging>=20.0
#   Downloading packaging-23.1-py3-none-any.whl (48 kB)
#      |████████████████████████████████| 48 kB 4.9 MB/s
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.39.3-py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 77.1 MB/s
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 72.7 MB/s
# Collecting dill>=0.2; python_version < "3.11"
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      |████████████████████████████████| 110 kB 73.8 MB/s
# Collecting astroid<=2.17.0-dev0,>=2.15.4
#   Downloading astroid-2.15.4-py3-none-any.whl (278 kB)
#      |████████████████████████████████| 278 kB 85.8 MB/s
# Collecting platformdirs>=2.2.0
#   Downloading platformdirs-3.5.0-py3-none-any.whl (15 kB)
# Collecting typing-extensions>=3.10.0; python_version < "3.10"
#   Downloading typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Collecting isort<6,>=4.2.5
#   Downloading isort-5.12.0-py3-none-any.whl (91 kB)
#      |████████████████████████████████| 91 kB 10.9 MB/s
# Collecting tomlkit>=0.10.1
#   Downloading tomlkit-0.11.8-py3-none-any.whl (35 kB)
# Collecting tomli>=1.1.0; python_version < "3.11"
#   Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Collecting mccabe<0.8,>=0.6
#   Downloading mccabe-0.7.0-py2.py3-none-any.whl (7.3 kB)
# Collecting tabulate>=0.8.9
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting portalocker
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Collecting lxml
#   Downloading lxml-4.9.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (7.1 MB)
#      |████████████████████████████████| 7.1 MB 80.3 MB/s
# Requirement already satisfied: regex in /usr/local/lib/python3.8/dist-packages (from sacrebleu>=2.0.0->joeynmt) (2023.5.5)
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting pandas>=0.25
#   Downloading pandas-2.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#      |████████████████████████████████| 12.3 MB 84.2 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from subword-nmt->joeynmt) (4.65.0)
# Collecting mock
#   Downloading mock-5.0.2-py3-none-any.whl (30 kB)
# Collecting protobuf>=3.19.6
#   Downloading protobuf-4.22.4-cp37-abi3-manylinux2014_x86_64.whl (302 kB)
#      |████████████████████████████████| 302 kB 90.9 MB/s
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.0-py3-none-manylinux2014_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 72.9 MB/s
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.17.3-py2.py3-none-any.whl (178 kB)
#      |████████████████████████████████| 178 kB 77.9 MB/s
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting requests<3,>=2.21.0
#   Downloading requests-2.30.0-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.1 MB/s
# Collecting grpcio>=1.48.2
#   Downloading grpcio-1.54.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#      |████████████████████████████████| 5.1 MB 69.5 MB/s
# Collecting werkzeug>=1.0.1
#   Downloading Werkzeug-2.3.3-py3-none-any.whl (242 kB)
#      |████████████████████████████████| 242 kB 81.6 MB/s
# Requirement already satisfied: wheel>=0.26 in /usr/lib/python3/dist-packages (from tensorboard>=1.15->joeynmt) (0.34.2)
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.4.3-py3-none-any.whl (93 kB)
#      |████████████████████████████████| 93 kB 2.7 MB/s
# Collecting absl-py>=0.4
#   Downloading absl_py-1.4.0-py3-none-any.whl (126 kB)
#      |████████████████████████████████| 126 kB 70.8 MB/s
# Collecting nvidia-nccl-cu11==2.14.3; platform_system == "Linux" and platform_machine == "x86_64"
#   Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl (177.1 MB)
#      |████████████████████████████████| 177.1 MB 75 kB/s
# Collecting networkx
#   Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 69.3 MB/s
# Collecting nvidia-cudnn-cu11==8.5.0.96; platform_system == "Linux" and platform_machine == "x86_64"
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      |████████████████████████████████| 557.1 MB 11 kB/s
# Collecting nvidia-cufft-cu11==10.9.0.58; platform_system == "Linux" and platform_machine == "x86_64"
#   Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl (168.4 MB)
#      |████████████████████████████████| 168.4 MB 59 kB/s
# Collecting triton==2.0.0; platform_system == "Linux" and platform_machine == "x86_64"
#   Downloading triton-2.0.0-1-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.2 MB)
#      |████████████████████████████████| 63.2 MB 4.2 kB/s
# Collecting jinja2
#   Downloading Jinja2-3.1.2-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 82.0 MB/s
# Collecting nvidia-cublas-cu11==11.10.3.66; platform_system == "Linux" and platform_machine == "x86_64"
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      |████████████████████████████████| 317.1 MB 24 kB/s
# Collecting nvidia-curand-cu11==10.2.10.91; platform_system == "Linux" and platform_machine == "x86_64"
#   Downloading nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
#      |████████████████████████████████| 54.6 MB 94 kB/s
# Collecting nvidia-cusolver-cu11==11.4.0.1; platform_system == "Linux" and platform_machine == "x86_64"
#   Downloading nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
#      |████████████████████████████████| 102.6 MB 5.1 kB/s
# Collecting nvidia-nvtx-cu11==11.7.91; platform_system == "Linux" and platform_machine == "x86_64"
#   Downloading nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
#      |████████████████████████████████| 98 kB 9.1 MB/s
# Collecting sympy
#   Downloading sympy-1.11.1-py3-none-any.whl (6.5 MB)
#      |████████████████████████████████| 6.5 MB 83.0 MB/s
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99; platform_system == "Linux" and platform_machine == "x86_64"
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      |████████████████████████████████| 21.0 MB 196 kB/s
# Collecting filelock
#   Downloading filelock-3.12.0-py3-none-any.whl (10 kB)
# Collecting nvidia-cuda-runtime-cu11==11.7.99; platform_system == "Linux" and platform_machine == "x86_64"
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      |████████████████████████████████| 849 kB 68.2 MB/s
# Collecting nvidia-cusparse-cu11==11.7.4.91; platform_system == "Linux" and platform_machine == "x86_64"
#   Downloading nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
#      |████████████████████████████████| 173.2 MB 30 kB/s
# Collecting nvidia-cuda-cupti-cu11==11.7.101; platform_system == "Linux" and platform_machine == "x86_64"
#   Downloading nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
#      |████████████████████████████████| 11.8 MB 81.1 MB/s
# Collecting torchdata==0.6.0
#   Downloading torchdata-0.6.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#      |████████████████████████████████| 4.6 MB 83.3 MB/s
# Collecting zipp>=3.1.0; python_version < "3.10"
#   Downloading zipp-3.15.0-py3-none-any.whl (6.8 kB)
# Collecting lazy-object-proxy>=1.4.0
#   Downloading lazy_object_proxy-1.9.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61 kB)
#      |████████████████████████████████| 61 kB 8.0 MB/s
# Collecting tzdata>=2022.1
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      |████████████████████████████████| 341 kB 78.9 MB/s
# Collecting pytz>=2020.1
#   Downloading pytz-2023.3-py2.py3-none-any.whl (502 kB)
#      |████████████████████████████████| 502 kB 76.8 MB/s
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 70.1 MB/s
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# Collecting rsa<5,>=3.1.4; python_version >= "3.6"
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2022.12.7-py3-none-any.whl (155 kB)
#      |████████████████████████████████| 155 kB 84.3 MB/s
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.1.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (195 kB)
#      |████████████████████████████████| 195 kB 70.6 MB/s
# Collecting idna<4,>=2.5
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 92 kB/s
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.0.2-py3-none-any.whl (123 kB)
#      |████████████████████████████████| 123 kB 76.5 MB/s
# Collecting MarkupSafe>=2.1.1
#   Downloading MarkupSafe-2.1.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting importlib-metadata>=4.4; python_version < "3.10"
#   Downloading importlib_metadata-6.6.0-py3-none-any.whl (22 kB)
# Collecting lit
#   Downloading lit-16.0.3.tar.gz (138 kB)
#      |████████████████████████████████| 138 kB 69.2 MB/s
# Collecting cmake
#   Downloading cmake-3.26.3-py2.py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (24.0 MB)
#      |████████████████████████████████| 24.0 MB 1.2 MB/s
# Collecting mpmath>=0.19
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      |████████████████████████████████| 536 kB 69.0 MB/s
# Collecting pyasn1<0.6.0,>=0.4.6
#   Downloading pyasn1-0.5.0-py2.py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 2.4 MB/s
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      |████████████████████████████████| 151 kB 79.9 MB/s
# Building wheels for collected packages: future, wrapt, lit
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.3-py3-none-any.whl size=492025 sha256=397260e9c4c0619dd467002d7d3fcf8f85c0836cd0db69dd5f39efd57fd104c5
#   Stored in directory: /root/.cache/pip/wheels/a0/0b/ee/e6994fadb42c1354dcccb139b0bf2795271bddfe6253ccdf11
#   Building wheel for wrapt (setup.py) ... done
#   Created wheel for wrapt: filename=wrapt-1.11.1-cp38-cp38-linux_x86_64.whl size=78268 sha256=8ffd35a61f44b5037bc5a49caa68b1ea98f2b6d5d36384b0563bc847a9b138f8
#   Stored in directory: /root/.cache/pip/wheels/90/d4/83/58efda72eb47567053254faec24fe048dced315a0c3f11e8f8
#   Building wheel for lit (setup.py) ... done
#   Created wheel for lit: filename=lit-16.0.3-py3-none-any.whl size=88191 sha256=c6debc4e3a0bb65f32714fb5d277d60edefb65fa44d5077b3b5d61b26af3cfdc
#   Stored in directory: /root/.cache/pip/wheels/01/20/c2/b32a74e477abe541734225f8d5ed8b9e284d1f8580f6828445
# Successfully built future wrapt lit
# Installing collected packages: future, zipp, importlib-resources, numpy, contourpy, cycler, pyparsing, python-dateutil, packaging, pillow, fonttools, kiwisolver, matplotlib, dill, typing-extensions, lazy-object-proxy, wrapt, astroid, platformdirs, isort, tomlkit, tomli, mccabe, pylint, pyyaml, tabulate, portalocker, lxml, colorama, sacrebleu, tzdata, pytz, pandas, seaborn, mock, subword-nmt, protobuf, tensorboard-data-server, pyasn1, pyasn1-modules, cachetools, rsa, google-auth, oauthlib, certifi, charset-normalizer, idna, urllib3, requests, requests-oauthlib, google-auth-oauthlib, grpcio, MarkupSafe, werkzeug, importlib-metadata, markdown, absl-py, tensorboard, nvidia-nccl-cu11, networkx, nvidia-cublas-cu11, nvidia-cudnn-cu11, nvidia-cufft-cu11, lit, filelock, cmake, triton, jinja2, nvidia-curand-cu11, nvidia-cusolver-cu11, nvidia-nvtx-cu11, mpmath, sympy, nvidia-cuda-nvrtc-cu11, nvidia-cuda-runtime-cu11, nvidia-cusparse-cu11, nvidia-cuda-cupti-cu11, torch, torchdata, torchtext, joeynmt
#   Running setup.py develop for joeynmt
# Successfully installed MarkupSafe-2.1.2 absl-py-1.4.0 astroid-2.15.4 cachetools-5.3.0 certifi-2022.12.7 charset-normalizer-3.1.0 cmake-3.26.3 colorama-0.4.6 contourpy-1.0.7 cycler-0.11.0 dill-0.3.6 filelock-3.12.0 fonttools-4.39.3 future-0.18.3 google-auth-2.17.3 google-auth-oauthlib-1.0.0 grpcio-1.54.0 idna-3.4 importlib-metadata-6.6.0 importlib-resources-5.12.0 isort-5.12.0 jinja2-3.1.2 joeynmt kiwisolver-1.4.4 lazy-object-proxy-1.9.0 lit-16.0.3 lxml-4.9.2 markdown-3.4.3 matplotlib-3.7.1 mccabe-0.7.0 mock-5.0.2 mpmath-1.3.0 networkx-3.1 numpy-1.24.3 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-nccl-cu11-2.14.3 nvidia-nvtx-cu11-11.7.91 oauthlib-3.2.2 packaging-23.1 pandas-2.0.1 pillow-9.5.0 platformdirs-3.5.0 portalocker-2.7.0 protobuf-4.22.4 pyasn1-0.5.0 pyasn1-modules-0.3.0 pylint-2.17.3 pyparsing-3.0.9 python-dateutil-2.8.2 pytz-2023.3 pyyaml-6.0 requests-2.30.0 requests-oauthlib-1.3.1 rsa-4.9 sacrebleu-2.3.1 seaborn-0.12.2 subword-nmt-0.3.8 sympy-1.11.1 tabulate-0.9.0 tensorboard-2.13.0 tensorboard-data-server-0.7.0 tomli-2.0.1 tomlkit-0.11.8 torch-2.0.0 torchdata-0.6.0 torchtext-0.15.1 triton-2.0.0 typing-extensions-4.5.0 tzdata-2023.3 urllib3-2.0.2 werkzeug-2.3.3 wrapt-1.11.1 zipp-3.15.0
# Cloning into 'joeynmt'...
# remote: Enumerating objects: 3292, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 3292 (delta 10), reused 9 (delta 9), pack-reused 3278
# Receiving objects: 100% (3292/3292), 8.10 MiB | 21.21 MiB/s, done.
# Resolving deltas: 100% (2279/2279), done.
# Note: switching to '092c504cb3d7b25b91cc37af4fbfe55af4faf64f'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Collecting torch==1.10.1+cu102
#   Downloading https://download.pytorch.org/whl/cu102/torch-1.10.1%2Bcu102-cp38-cp38-linux_x86_64.whl (881.9 MB)
#      |████████████████████████████████| 881.9 MB 7.7 kB/s
# Collecting torchtext==0.11.1
#   Downloading torchtext-0.11.1-cp38-cp38-manylinux1_x86_64.whl (8.0 MB)
#      |████████████████████████████████| 8.0 MB 4.5 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch==1.10.1+cu102) (4.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from torchtext==0.11.1) (1.24.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from torchtext==0.11.1) (4.65.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from torchtext==0.11.1) (2.30.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext==0.11.1) (3.1.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext==0.11.1) (2.0.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext==0.11.1) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->torchtext==0.11.1) (2022.12.7)
# ERROR: torchdata 0.6.0 has requirement torch==2.0.0, but you'll have torch 1.10.1+cu102 which is incompatible.
# Installing collected packages: torch, torchtext
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.0
#     Uninstalling torch-2.0.0:
#       Successfully uninstalled torch-2.0.0
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.15.1
#     Uninstalling torchtext-0.15.1:
#       Successfully uninstalled torchtext-0.15.1
# Successfully installed torch-1.10.1+cu102 torchtext-0.11.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting setuptools==59.5.0
#   Downloading setuptools-59.5.0-py3-none-any.whl (952 kB)
#      |████████████████████████████████| 952 kB 4.4 MB/s
# Installing collected packages: setuptools
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 45.2.0
#     Not uninstalling setuptools at /usr/lib/python3/dist-packages, outside environment /usr
#     Can't uninstall 'setuptools'. No files were found to uninstall.
# Successfully installed setuptools-59.5.0

# %% [markdown]
# # Preprocessing the Data into Subword BPE Tokens
#
# - One of the most powerful improvements for open vocabulary NMT is using BPE tokenization [ (Sennrich, 2015) ](https://arxiv.org/abs/1508.07909).
#
# - It was also shown that by optimizing the number of BPE codes we significantly improve results for low-resourced languages [(Sennrich, 2019)](https://www.aclweb.org/anthology/P19-1021) [(Martinus, 2019)](https://arxiv.org/abs/1906.05685)
#
# - Below we have the scripts for doing BPE tokenization of our data. We use 4000 tokens as recommended by [(Sennrich, 2019)](https://www.aclweb.org/anthology/P19-1021). You do not need to change anything. Simply running the below will be suitable.

# %%
# One of the huge boosts in NMT performance was to use a different method of tokenizing. 
# Usually, NMT would tokenize by words. However, using a method called BPE gave amazing boosts to performance

# Do subword NMT
from os import path
os.environ["src"] = source_language # Sets them in bash as well, since we often use bash scripts
os.environ["tgt"] = target_language

# Learn BPEs on the training data.
os.environ["data_path"] = path.join("joeynmt", "data", source_language + target_language) 
! subword-nmt learn-joint-bpe-and-vocab --input train.$src train.$tgt -s 4000 -o bpe.codes.4000 --write-vocabulary vocab.$src vocab.$tgt

# Apply BPE splits to the development and test data.
! subword-nmt apply-bpe -c bpe.codes.4000 --vocabulary vocab.$src < train.$src > train.bpe.$src
! subword-nmt apply-bpe -c bpe.codes.4000 --vocabulary vocab.$tgt < train.$tgt > train.bpe.$tgt

! subword-nmt apply-bpe -c bpe.codes.4000 --vocabulary vocab.$src < dev.$src > dev.bpe.$src
! subword-nmt apply-bpe -c bpe.codes.4000 --vocabulary vocab.$tgt < dev.$tgt > dev.bpe.$tgt
! subword-nmt apply-bpe -c bpe.codes.4000 --vocabulary vocab.$src < test.$src > test.bpe.$src
! subword-nmt apply-bpe -c bpe.codes.4000 --vocabulary vocab.$tgt < test.$tgt > test.bpe.$tgt

# Create directory, move everyone we care about to the correct location
! mkdir -p "$data_path"
! cp train.* "$data_path"
! cp test.* "$data_path"
! cp dev.* "$data_path"
! cp bpe.codes.4000 "$data_path"
! ls "$data_path"

# Also move everything we care about to a mounted location in google drive (relevant if running in colab) at gdrive_path
! cp train.* "$gdrive_path"
! cp test.* "$gdrive_path"
! cp dev.* "$gdrive_path"
! cp bpe.codes.4000 "$gdrive_path"
! ls "$gdrive_path"

# Create that vocab using build_vocab
! sudo chmod 777 joeynmt/scripts/build_vocab.py
! joeynmt/scripts/build_vocab.py joeynmt/data/$src$tgt/train.bpe.$src joeynmt/data/$src$tgt/train.bpe.$tgt --output_path joeynmt/data/$src$tgt/vocab.txt

# Some output
! echo "BPE Test language Sentences"
! tail -n 5 test.bpe.$tgt
! echo "Combined BPE Vocab"
! tail -n 10 joeynmt/data/$src$tgt/vocab.txt
# Out:
# 100% 4000/4000 [00:26<00:00, 149.49it/s]
# bpe.codes.4000	dev.en	     test.bpe.fr  train.bpe.en	train.fr
# dev.bpe.en	dev.fr	     test.en	  train.bpe.fr
# dev.bpe.fr	test.bpe.en  test.fr	  train.en
# bpe.codes.4000	dev.en	     test.bpe.fr  train.bpe.en	train.fr
# dev.bpe.en	dev.fr	     test.en	  train.bpe.fr
# dev.bpe.fr	test.bpe.en  test.fr	  train.en
# BPE Test language Sentences
# Il y a des éléments de preuve clai@@ rs dans les pi@@ è@@ ces du dossi@@ er .
# Le minis@@ t@@ ère public est d&apos; avis qu&apos; il n&apos; ent@@ end pas contra@@ indre cette personne à té@@ mo@@ ign@@ er bien qu&apos; il existe des éléments de preuve convain@@ c@@ ants sur ces questions .
# Il s&apos; agit d&apos; un pouvoir dis@@ cré@@ tionn@@ aire que , je le cra@@ ins , je n&apos; exer@@ cer@@ ai pas en votre faveur . »
# Le requ@@ ér@@ ant inter@@ jet@@ a appe@@ l et il fu@@ t déb@@ ou@@ té le 1@@ 4 nov@@ embre 2003 avec l&apos; expli@@ cation suiv@@ ante : « P@@ our pouvoir être con@@ t@@ est@@ ée en appe@@ l en tant que s@@ ent@@ ence , la décision doit faire suite à une con@@ dam@@ n@@ ation .
# O@@ r la décision de rem@@ bour@@ s@@ er les dé@@ p@@ ens du déf@@ end@@ eur n&apos; étant prise que lorsque l&apos; action publique n&apos; a pas ab@@ out@@ i , elle ne constitue pas une s@@ ent@@ ence et ne peut donc faire l&apos; objet d&apos; un re@@ cours devant la ch@@ am@@ b@@ re crimin@@ elle de la Cour d&apos; appe@@ l . »
# Combined BPE Vocab
# Ú
# ć@@
# ÷
# Ñ@@
# Ì
# –@@
# ·@@
# ș
# ů@@
# È

# %%
# Also move everything we care about to a mounted location in google drive (relevant if running in colab) at gdrive_path
! cp train.* "$gdrive_path"
! cp test.* "$gdrive_path"
! cp echr_test.* "$gdrive_path"
! cp dev.* "$gdrive_path"
! cp bpe.codes.4000 "$gdrive_path"
! ls "$gdrive_path"
# Out:
# cp: cannot stat 'echr_test.*': No such file or directory
# bpe.codes.4000	dev.en	     test.bpe.fr  train.bpe.en	train.fr
# dev.bpe.en	dev.fr	     test.en	  train.bpe.fr
# dev.bpe.fr	test.bpe.en  test.fr	  train.en

# %% [markdown]
# # Creating the JoeyNMT Config
#
# JoeyNMT requires a yaml config. We provide a template below. We've also set a number of defaults with it, that you may play with!
#
# - We used Transformer architecture
# - We set our dropout to reasonably high: 0.3 (recommended in  [(Sennrich, 2019)](https://www.aclweb.org/anthology/P19-1021))
#
# Things worth playing with:
# - The batch size (also recommended to change for low-resourced languages)
# - The number of epochs (we've set it at 30 just so it runs in about an hour, for testing purposes)
# - The decoder options (beam_size, alpha)
# - Evaluation metrics (BLEU versus Crhf4)

# %%
# This creates the config file for our JoeyNMT system. It might seem overwhelming so we've provided a couple of useful parameters you'll need to update
# (You can of course play with all the parameters if you'd like!)

name = '%s%s' % (source_language, target_language)
gdrive_path = os.environ["gdrive_path"]

# Create the config
config = """
name: "{name}_transformer"

data:
    src: "{source_language}"
    trg: "{target_language}"
    train: "data/{name}/train.bpe"
    dev:   "data/{name}/dev.bpe"
    test:  "data/{name}/test.bpe"
    level: "bpe"
    lowercase: False
    max_sent_length: 100
    src_vocab: "data/{name}/vocab.txt"
    trg_vocab: "data/{name}/vocab.txt"

testing:
    beam_size: 5
    alpha: 1.0
    sacrebleu:                      # sacrebleu options
        remove_whitespace: True     # `remove_whitespace` option in sacrebleu.corpus_chrf() function (defalut: True)
        tokenize: "none"            # `tokenize` option in sacrebleu.corpus_bleu() function (options include: "none" (use for already tokenized test data), "13a" (default minimal tokenizer), "intl" which mostly does punctuation and unicode, etc) 

training:
    #load_model: "{gdrive_path}/models/{name}_transformer/1.ckpt" # if uncommented, load a pre-trained model from this checkpoint
    random_seed: 42
    optimizer: "adam"
    normalization: "tokens"
    adam_betas: [0.9, 0.999] 
    scheduling: "noam"           # TODO: try switching from plateau to Noam scheduling
    patience: 5                     # For plateau: decrease learning rate by decrease_factor if validation score has not improved for this many validation rounds.
    learning_rate_factor: 0.5       # factor for Noam scheduler (used with Transformer)
    learning_rate_warmup: 1000      # warmup steps for Noam scheduler (used with Transformer)
    decrease_factor: 0.7
    loss: "crossentropy"
    learning_rate: 0.0003
    learning_rate_min: 0.00000001
    weight_decay: 0.0
    label_smoothing: 0.1
    batch_size: 4096
    batch_type: "token"
    eval_batch_size: 3600
    eval_batch_type: "token"
    batch_multiplier: 1
    early_stopping_metric: "ppl"
    epochs: 1                     # TODO: Decrease for when playing around and checking of working. Around 30 is sufficient to check if its working at all
    validation_freq: 1000          # TODO: Set to at least once per epoch.
    logging_freq: 100
    eval_metric: "bleu"
    model_dir: "models/{name}_transformer"
    overwrite: True               # TODO: Set to True if you want to overwrite possibly existing models. 
    shuffle: True
    use_cuda: True
    max_output_length: 100
    print_valid_sents: [0, 1, 2, 3]
    keep_last_ckpts: 3

model:
    initializer: "xavier"
    bias_initializer: "zeros"
    init_gain: 1.0
    embed_initializer: "xavier"
    embed_init_gain: 1.0
    tied_embeddings: True
    tied_softmax: True
    encoder:
        type: "transformer"
        num_layers: 6
        num_heads: 4             # TODO: Increase to 8 for larger data.
        embeddings:
            embedding_dim: 256   # TODO: Increase to 512 for larger data.
            scale: True
            dropout: 0.2
        # typically ff_size = 4 x hidden_size
        hidden_size: 256         # TODO: Increase to 512 for larger data.
        ff_size: 1024            # TODO: Increase to 2048 for larger data.
        dropout: 0.3
    decoder:
        type: "transformer"
        num_layers: 6
        num_heads: 4              # TODO: Increase to 8 for larger data.
        embeddings:
            embedding_dim: 256    # TODO: Increase to 512 for larger data.
            scale: True
            dropout: 0.2
        # typically ff_size = 4 x hidden_size
        hidden_size: 256         # TODO: Increase to 512 for larger data.
        ff_size: 1024            # TODO: Increase to 2048 for larger data.
        dropout: 0.3
""".format(name=name, gdrive_path=os.environ["gdrive_path"], source_language=source_language, target_language=target_language)
with open("joeynmt/configs/transformer_{name}.yaml".format(name=name),'w') as f:
    f.write(config)

# %% [markdown]
# # Train the Model
#
# This single line of joeynmt runs the training using the config we made above

# %%
# Train the model
# You can press Ctrl-C to stop. And then run the next cell to save your checkpoints! 
# !cd joeynmt; python3 -m joeynmt train configs/transformer_$src$tgt.yaml
# Out:
# 2023-05-06 13:16:39,436 - INFO - root - Hello! This is Joey-NMT (version 1.5).
# 2023-05-06 13:16:39,493 - INFO - joeynmt.data - Loading training data...
# 2023-05-06 13:17:40,182 - INFO - joeynmt.data - Building vocabulary...
# 2023-05-06 13:17:40,420 - INFO - joeynmt.data - Loading dev data...
# 2023-05-06 13:17:40,545 - INFO - joeynmt.data - Loading test data...
# 2023-05-06 13:17:40,550 - INFO - joeynmt.data - Data loaded.
# 2023-05-06 13:17:40,550 - INFO - joeynmt.model - Building an encoder-decoder model...
# 2023-05-06 13:17:41,015 - INFO - joeynmt.model - Enc-dec model built.
# 2023-05-06 13:17:41,026 - INFO - joeynmt.training - Total params: 12211712
# 2023-05-06 13:17:41,030 - WARNING - joeynmt.training - `keep_last_ckpts` option is outdated. Please use `keep_best_ckpts`, instead.
# 2023-05-06 13:17:48,160 - INFO - joeynmt.helpers -                           cfg.name : enfr_transformer
# 2023-05-06 13:17:48,160 - INFO - joeynmt.helpers -                       cfg.data.src : en
# 2023-05-06 13:17:48,160 - INFO - joeynmt.helpers -                       cfg.data.trg : fr
# 2023-05-06 13:17:48,160 - INFO - joeynmt.helpers -                     cfg.data.train : data/enfr/train.bpe
# 2023-05-06 13:17:48,160 - INFO - joeynmt.helpers -                       cfg.data.dev : data/enfr/dev.bpe
# 2023-05-06 13:17:48,160 - INFO - joeynmt.helpers -                      cfg.data.test : data/enfr/test.bpe
# 2023-05-06 13:17:48,160 - INFO - joeynmt.helpers -                     cfg.data.level : bpe
# 2023-05-06 13:17:48,160 - INFO - joeynmt.helpers -                 cfg.data.lowercase : False
# 2023-05-06 13:17:48,160 - INFO - joeynmt.helpers -           cfg.data.max_sent_length : 100
# 2023-05-06 13:17:48,160 - INFO - joeynmt.helpers -                 cfg.data.src_vocab : data/enfr/vocab.txt
# 2023-05-06 13:17:48,160 - INFO - joeynmt.helpers -                 cfg.data.trg_vocab : data/enfr/vocab.txt
# 2023-05-06 13:17:48,160 - INFO - joeynmt.helpers -              cfg.testing.beam_size : 5
# 2023-05-06 13:17:48,160 - INFO - joeynmt.helpers -                  cfg.testing.alpha : 1.0
# 2023-05-06 13:17:48,160 - INFO - joeynmt.helpers - cfg.testing.sacrebleu.remove_whitespace : True
# 2023-05-06 13:17:48,161 - INFO - joeynmt.helpers -     cfg.testing.sacrebleu.tokenize : none
# 2023-05-06 13:17:48,161 - INFO - joeynmt.helpers -           cfg.training.random_seed : 42
# 2023-05-06 13:17:48,161 - INFO - joeynmt.helpers -             cfg.training.optimizer : adam
# 2023-05-06 13:17:48,161 - INFO - joeynmt.helpers -         cfg.training.normalization : tokens
# 2023-05-06 13:17:48,161 - INFO - joeynmt.helpers -            cfg.training.adam_betas : [0.9, 0.999]
# 2023-05-06 13:17:48,161 - INFO - joeynmt.helpers -            cfg.training.scheduling : noam
# 2023-05-06 13:17:48,161 - INFO - joeynmt.helpers -              cfg.training.patience : 5
# 2023-05-06 13:17:48,161 - INFO - joeynmt.helpers -  cfg.training.learning_rate_factor : 0.5
# 2023-05-06 13:17:48,161 - INFO - joeynmt.helpers -  cfg.training.learning_rate_warmup : 1000
# 2023-05-06 13:17:48,161 - INFO - joeynmt.helpers -       cfg.training.decrease_factor : 0.7
# 2023-05-06 13:17:48,161 - INFO - joeynmt.helpers -                  cfg.training.loss : crossentropy
# 2023-05-06 13:17:48,161 - INFO - joeynmt.helpers -         cfg.training.learning_rate : 0.0003
# 2023-05-06 13:17:48,161 - INFO - joeynmt.helpers -     cfg.training.learning_rate_min : 1e-08
# 2023-05-06 13:17:48,161 - INFO - joeynmt.helpers -          cfg.training.weight_decay : 0.0
# 2023-05-06 13:17:48,161 - INFO - joeynmt.helpers -       cfg.training.label_smoothing : 0.1
# 2023-05-06 13:17:48,161 - INFO - joeynmt.helpers -            cfg.training.batch_size : 4096
# 2023-05-06 13:17:48,161 - INFO - joeynmt.helpers -            cfg.training.batch_type : token
# 2023-05-06 13:17:48,161 - INFO - joeynmt.helpers -       cfg.training.eval_batch_size : 3600
# 2023-05-06 13:17:48,161 - INFO - joeynmt.helpers -       cfg.training.eval_batch_type : token
# 2023-05-06 13:17:48,161 - INFO - joeynmt.helpers -      cfg.training.batch_multiplier : 1
# 2023-05-06 13:17:48,161 - INFO - joeynmt.helpers - cfg.training.early_stopping_metric : ppl
# 2023-05-06 13:17:48,161 - INFO - joeynmt.helpers -                cfg.training.epochs : 1
# 2023-05-06 13:17:48,161 - INFO - joeynmt.helpers -       cfg.training.validation_freq : 1000
# 2023-05-06 13:17:48,161 - INFO - joeynmt.helpers -          cfg.training.logging_freq : 100
# 2023-05-06 13:17:48,161 - INFO - joeynmt.helpers -           cfg.training.eval_metric : bleu
# 2023-05-06 13:17:48,162 - INFO - joeynmt.helpers -             cfg.training.model_dir : models/enfr_transformer
# 2023-05-06 13:17:48,162 - INFO - joeynmt.helpers -             cfg.training.overwrite : True
# 2023-05-06 13:17:48,162 - INFO - joeynmt.helpers -               cfg.training.shuffle : True
# 2023-05-06 13:17:48,162 - INFO - joeynmt.helpers -              cfg.training.use_cuda : True
# 2023-05-06 13:17:48,162 - INFO - joeynmt.helpers -     cfg.training.max_output_length : 100
# 2023-05-06 13:17:48,162 - INFO - joeynmt.helpers -     cfg.training.print_valid_sents : [0, 1, 2, 3]
# 2023-05-06 13:17:48,162 - INFO - joeynmt.helpers -       cfg.training.keep_last_ckpts : 3
# 2023-05-06 13:17:48,162 - INFO - joeynmt.helpers -              cfg.model.initializer : xavier
# 2023-05-06 13:17:48,162 - INFO - joeynmt.helpers -         cfg.model.bias_initializer : zeros
# 2023-05-06 13:17:48,162 - INFO - joeynmt.helpers -                cfg.model.init_gain : 1.0
# 2023-05-06 13:17:48,162 - INFO - joeynmt.helpers -        cfg.model.embed_initializer : xavier
# 2023-05-06 13:17:48,162 - INFO - joeynmt.helpers -          cfg.model.embed_init_gain : 1.0
# 2023-05-06 13:17:48,162 - INFO - joeynmt.helpers -          cfg.model.tied_embeddings : True
# 2023-05-06 13:17:48,162 - INFO - joeynmt.helpers -             cfg.model.tied_softmax : True
# 2023-05-06 13:17:48,162 - INFO - joeynmt.helpers -             cfg.model.encoder.type : transformer
# 2023-05-06 13:17:48,162 - INFO - joeynmt.helpers -       cfg.model.encoder.num_layers : 6
# 2023-05-06 13:17:48,162 - INFO - joeynmt.helpers -        cfg.model.encoder.num_heads : 4
# 2023-05-06 13:17:48,162 - INFO - joeynmt.helpers - cfg.model.encoder.embeddings.embedding_dim : 256
# 2023-05-06 13:17:48,162 - INFO - joeynmt.helpers - cfg.model.encoder.embeddings.scale : True
# 2023-05-06 13:17:48,162 - INFO - joeynmt.helpers - cfg.model.encoder.embeddings.dropout : 0.2
# 2023-05-06 13:17:48,162 - INFO - joeynmt.helpers -      cfg.model.encoder.hidden_size : 256
# 2023-05-06 13:17:48,162 - INFO - joeynmt.helpers -          cfg.model.encoder.ff_size : 1024
# 2023-05-06 13:17:48,163 - INFO - joeynmt.helpers -          cfg.model.encoder.dropout : 0.3
# 2023-05-06 13:17:48,163 - INFO - joeynmt.helpers -             cfg.model.decoder.type : transformer
# 2023-05-06 13:17:48,163 - INFO - joeynmt.helpers -       cfg.model.decoder.num_layers : 6
# 2023-05-06 13:17:48,163 - INFO - joeynmt.helpers -        cfg.model.decoder.num_heads : 4
# 2023-05-06 13:17:48,163 - INFO - joeynmt.helpers - cfg.model.decoder.embeddings.embedding_dim : 256
# 2023-05-06 13:17:48,163 - INFO - joeynmt.helpers - cfg.model.decoder.embeddings.scale : True
# 2023-05-06 13:17:48,163 - INFO - joeynmt.helpers - cfg.model.decoder.embeddings.dropout : 0.2
# 2023-05-06 13:17:48,163 - INFO - joeynmt.helpers -      cfg.model.decoder.hidden_size : 256
# 2023-05-06 13:17:48,163 - INFO - joeynmt.helpers -          cfg.model.decoder.ff_size : 1024
# 2023-05-06 13:17:48,163 - INFO - joeynmt.helpers -          cfg.model.decoder.dropout : 0.3
# 2023-05-06 13:17:48,163 - INFO - joeynmt.helpers - Data set sizes:
# 	train 1882796,
# 	valid 1000,
# 	test 330
# 2023-05-06 13:17:48,163 - INFO - joeynmt.helpers - First training example:
# 	[SRC] We can therefore con@@ duc@@ t this debate again with those who really know the rop@@ es and who do not believe it is enough simply to im@@ pose standards .
# 	[TRG] L ’ adoption de l ’ amendement port@@ ant sur cette dis@@ position est capit@@ ale .
# 2023-05-06 13:17:48,163 - INFO - joeynmt.helpers - First 10 words (src): (0) <unk> (1) <pad> (2) <s> (3) </s> (4) , (5) the (6) de (7) ." (8) of (9) la
# 2023-05-06 13:17:48,163 - INFO - joeynmt.helpers - First 10 words (trg): (0) <unk> (1) <pad> (2) <s> (3) </s> (4) , (5) the (6) de (7) ." (8) of (9) la
# 2023-05-06 13:17:48,163 - INFO - joeynmt.helpers - Number of Src words (types): 4498
# 2023-05-06 13:17:48,164 - INFO - joeynmt.helpers - Number of Trg words (types): 4498
# 2023-05-06 13:17:48,164 - INFO - joeynmt.training - Model(
# 	encoder=TransformerEncoder(num_layers=6, num_heads=4),
# 	decoder=TransformerDecoder(num_layers=6, num_heads=4),
# 	src_embed=Embeddings(embedding_dim=256, vocab_size=4498),
# 	trg_embed=Embeddings(embedding_dim=256, vocab_size=4498))
# 2023-05-06 13:17:48,166 - INFO - joeynmt.training - Train stats:
# 	device: cuda
# 	n_gpu: 1
# 	16-bits training: False
# 	gradient accumulation: 1
# 	batch size per device: 4096
# 	total batch size (w. parallel & accumulation): 4096
# 2023-05-06 13:17:48,167 - INFO - joeynmt.training - EPOCH 1
# 2023-05-06 13:18:08,065 - INFO - joeynmt.training - Epoch   1, Step:      100, Batch Loss:     6.201321, Tokens per Sec:     8993, Lr: 0.000099
# 2023-05-06 13:18:24,456 - INFO - joeynmt.training - Epoch   1, Step:      200, Batch Loss:     5.754614, Tokens per Sec:    10997, Lr: 0.000198
# 2023-05-06 13:18:40,828 - INFO - joeynmt.training - Epoch   1, Step:      300, Batch Loss:     5.489388, Tokens per Sec:    11176, Lr: 0.000296
# 2023-05-06 13:18:57,231 - INFO - joeynmt.training - Epoch   1, Step:      400, Batch Loss:     5.326621, Tokens per Sec:    11124, Lr: 0.000395
# 2023-05-06 13:19:13,821 - INFO - joeynmt.training - Epoch   1, Step:      500, Batch Loss:     4.945228, Tokens per Sec:    11097, Lr: 0.000494
# 2023-05-06 13:19:30,401 - INFO - joeynmt.training - Epoch   1, Step:      600, Batch Loss:     4.681701, Tokens per Sec:    10789, Lr: 0.000593
# 2023-05-06 13:19:47,386 - INFO - joeynmt.training - Epoch   1, Step:      700, Batch Loss:     4.583209, Tokens per Sec:    10569, Lr: 0.000692
# 2023-05-06 13:20:04,394 - INFO - joeynmt.training - Epoch   1, Step:      800, Batch Loss:     4.358853, Tokens per Sec:    10670, Lr: 0.000791
# 2023-05-06 13:20:21,327 - INFO - joeynmt.training - Epoch   1, Step:      900, Batch Loss:     4.178102, Tokens per Sec:    10665, Lr: 0.000889
# 2023-05-06 13:20:38,309 - INFO - joeynmt.training - Epoch   1, Step:     1000, Batch Loss:     4.098899, Tokens per Sec:    10621, Lr: 0.000988
# 2023-05-06 13:21:20,487 - WARNING - sacrebleu - That's 100 lines that end in a tokenized period ('.')
# 2023-05-06 13:21:20,487 - WARNING - sacrebleu - It looks like you forgot to detokenize your test data, which may hurt your score.
# 2023-05-06 13:21:20,487 - WARNING - sacrebleu - If you insist your data is detokenized, or don't care, you can suppress this message with the `force` parameter.
# 2023-05-06 13:21:20,504 - INFO - joeynmt.training - Hooray! New best validation result [ppl]!
# 2023-05-06 13:21:20,849 - INFO - joeynmt.training - Example #0
# 2023-05-06 13:21:20,849 - INFO - joeynmt.training - 	Source:     The regions need to be given room to invest in their infrastructure and people according to their own priorities .
# 2023-05-06 13:21:20,849 - INFO - joeynmt.training - 	Reference:  Les régions doivent avoir la possibilité d&apos; investir dans leur infrastructure et leurs citoyens en fonction des priorités qui leur sont propres .
# 2023-05-06 13:21:20,849 - INFO - joeynmt.training - 	Hypothesis: La Commission est pas de la question de la politique de la politique de la politique de l&apos; Union européenne .
# 2023-05-06 13:21:20,849 - INFO - joeynmt.training - Example #1
# 2023-05-06 13:21:20,850 - INFO - joeynmt.training - 	Source:     I think we should have a rule that we should know at least two hours in advance who will take the floor in the one-minute speeches .
# 2023-05-06 13:21:20,850 - INFO - joeynmt.training - 	Reference:  Je pense qu&apos; il devrait y avoir une règle pour que nous sachions au moins deux heures à l&apos; avance qui s&apos; exprimera dans les interventions d&apos; une minute .
# 2023-05-06 13:21:20,850 - INFO - joeynmt.training - 	Hypothesis: "Je pense que nous devons être être un accord , nous devons être être un peu de la question de la question de la question de la question de la question de la question de la question de la question de la question ."
# 2023-05-06 13:21:20,850 - INFO - joeynmt.training - Example #2
# 2023-05-06 13:21:20,850 - INFO - joeynmt.training - 	Source:     "The President allocated me two minutes and thirty seconds , and I would like to make full use of them ."
# 2023-05-06 13:21:20,850 - INFO - joeynmt.training - 	Reference:  Le président m ’ a accordé deux minutes et trente secondes et je voudrais les utiliser pleinement .
# 2023-05-06 13:21:20,850 - INFO - joeynmt.training - 	Hypothesis: "Monsieur le Président , Monsieur le Président , Monsieur le Président , je suis pas de la question de la Commission , je suis pas de la question ."
# 2023-05-06 13:21:20,850 - INFO - joeynmt.training - Example #3
# 2023-05-06 13:21:20,850 - INFO - joeynmt.training - 	Source:     It is therefore right to recommend that greater regulation be imposed on European football and that this should be connected with European law and the dynamics of the internal market .
# 2023-05-06 13:21:20,850 - INFO - joeynmt.training - 	Reference:  Il est donc normal de recommander que des réglementations plus strictes soient imposées au football européen et que celles-ci soient liées par la législation européenne et la dynamique du marché intérieur .
# 2023-05-06 13:21:20,850 - INFO - joeynmt.training - 	Hypothesis: Il est pourquoi nous devons être être un accord de la Commission ne peut pas pas pas pas de la Commission et la Commission et de la Commission européenne .
# 2023-05-06 13:21:20,850 - INFO - joeynmt.training - Validation result (greedy) at epoch   1, step     1000: bleu:   1.65, loss: 169931.1719, ppl:  53.4984, duration: 42.5408s
# 2023-05-06 13:21:38,147 - INFO - joeynmt.training - Epoch   1, Step:     1100, Batch Loss:     3.850061, Tokens per Sec:    10327, Lr: 0.000942
# 2023-05-06 13:21:55,450 - INFO - joeynmt.training - Epoch   1, Step:     1200, Batch Loss:     3.791090, Tokens per Sec:    10454, Lr: 0.000902
# 2023-05-06 13:22:12,783 - INFO - joeynmt.training - Epoch   1, Step:     1300, Batch Loss:     3.662273, Tokens per Sec:    10305, Lr: 0.000867
# 2023-05-06 13:22:30,100 - INFO - joeynmt.training - Epoch   1, Step:     1400, Batch Loss:     3.677009, Tokens per Sec:    10312, Lr: 0.000835
# 2023-05-06 13:22:47,533 - INFO - joeynmt.training - Epoch   1, Step:     1500, Batch Loss:     3.586117, Tokens per Sec:    10314, Lr: 0.000807
# 2023-05-06 13:23:04,803 - INFO - joeynmt.training - Epoch   1, Step:     1600, Batch Loss:     3.678887, Tokens per Sec:    10528, Lr: 0.000781
# 2023-05-06 13:23:22,274 - INFO - joeynmt.training - Epoch   1, Step:     1700, Batch Loss:     3.579455, Tokens per Sec:    10494, Lr: 0.000758
# 2023-05-06 13:23:39,628 - INFO - joeynmt.training - Epoch   1, Step:     1800, Batch Loss:     3.555631, Tokens per Sec:    10374, Lr: 0.000737
# 2023-05-06 13:23:57,076 - INFO - joeynmt.training - Epoch   1, Step:     1900, Batch Loss:     3.368471, Tokens per Sec:    10409, Lr: 0.000717
# 2023-05-06 13:24:14,607 - INFO - joeynmt.training - Epoch   1, Step:     2000, Batch Loss:     3.420266, Tokens per Sec:    10336, Lr: 0.000699
# 2023-05-06 13:24:58,643 - WARNING - sacrebleu - That's 100 lines that end in a tokenized period ('.')
# 2023-05-06 13:24:58,643 - WARNING - sacrebleu - It looks like you forgot to detokenize your test data, which may hurt your score.
# 2023-05-06 13:24:58,643 - WARNING - sacrebleu - If you insist your data is detokenized, or don't care, you can suppress this message with the `force` parameter.
# 2023-05-06 13:24:58,656 - INFO - joeynmt.training - Hooray! New best validation result [ppl]!
# 2023-05-06 13:24:59,030 - INFO - joeynmt.training - Example #0
# 2023-05-06 13:24:59,031 - INFO - joeynmt.training - 	Source:     The regions need to be given room to invest in their infrastructure and people according to their own priorities .
# 2023-05-06 13:24:59,031 - INFO - joeynmt.training - 	Reference:  Les régions doivent avoir la possibilité d&apos; investir dans leur infrastructure et leurs citoyens en fonction des priorités qui leur sont propres .
# 2023-05-06 13:24:59,031 - INFO - joeynmt.training - 	Hypothesis: Les régions doivent être prises à l&apos; aide et les autorités de l&apos; aide et les pays qui sont les plus importantes .
# 2023-05-06 13:24:59,031 - INFO - joeynmt.training - Example #1
# 2023-05-06 13:24:59,031 - INFO - joeynmt.training - 	Source:     I think we should have a rule that we should know at least two hours in advance who will take the floor in the one-minute speeches .
# 2023-05-06 13:24:59,031 - INFO - joeynmt.training - 	Reference:  Je pense qu&apos; il devrait y avoir une règle pour que nous sachions au moins deux heures à l&apos; avance qui s&apos; exprimera dans les interventions d&apos; une minute .
# 2023-05-06 13:24:59,031 - INFO - joeynmt.training - 	Hypothesis: Je crois que nous devons être en effet que nous devons être considéré en ce qui concerne les deux ans .
# 2023-05-06 13:24:59,031 - INFO - joeynmt.training - Example #2
# 2023-05-06 13:24:59,032 - INFO - joeynmt.training - 	Source:     "The President allocated me two minutes and thirty seconds , and I would like to make full use of them ."
# 2023-05-06 13:24:59,032 - INFO - joeynmt.training - 	Reference:  Le président m ’ a accordé deux minutes et trente secondes et je voudrais les utiliser pleinement .
# 2023-05-06 13:24:59,032 - INFO - joeynmt.training - 	Hypothesis: "Le Conseil a été été été réusés et je vous remercie , et je voudrais remercier , et je voudrais remercier les réfusions ."
# 2023-05-06 13:24:59,032 - INFO - joeynmt.training - Example #3
# 2023-05-06 13:24:59,032 - INFO - joeynmt.training - 	Source:     It is therefore right to recommend that greater regulation be imposed on European football and that this should be connected with European law and the dynamics of the internal market .
# 2023-05-06 13:24:59,032 - INFO - joeynmt.training - 	Reference:  Il est donc normal de recommander que des réglementations plus strictes soient imposées au football européen et que celles-ci soient liées par la législation européenne et la dynamique du marché intérieur .
# 2023-05-06 13:24:59,032 - INFO - joeynmt.training - 	Hypothesis: Il est important que le système européen est nécessaire pour assurer que les réfugiés et les réfugiés et nous devons être prises à la situation européenne et de la protection des consommateurs .
# 2023-05-06 13:24:59,032 - INFO - joeynmt.training - Validation result (greedy) at epoch   1, step     2000: bleu:   4.11, loss: 139320.6875, ppl:  26.1220, duration: 44.4247s
# 2023-05-06 13:25:16,482 - INFO - joeynmt.training - Epoch   1, Step:     2100, Batch Loss:     3.301744, Tokens per Sec:    10368, Lr: 0.000682
# 2023-05-06 13:25:33,998 - INFO - joeynmt.training - Epoch   1, Step:     2200, Batch Loss:     3.234678, Tokens per Sec:    10476, Lr: 0.000666
# 2023-05-06 13:25:51,378 - INFO - joeynmt.training - Epoch   1, Step:     2300, Batch Loss:     3.320905, Tokens per Sec:    10293, Lr: 0.000652
# 2023-05-06 13:26:08,892 - INFO - joeynmt.training - Epoch   1, Step:     2400, Batch Loss:     3.321757, Tokens per Sec:    10178, Lr: 0.000638
# 2023-05-06 13:26:26,295 - INFO - joeynmt.training - Epoch   1, Step:     2500, Batch Loss:     3.177510, Tokens per Sec:    10414, Lr: 0.000625
# 2023-05-06 13:26:43,771 - INFO - joeynmt.training - Epoch   1, Step:     2600, Batch Loss:     3.222754, Tokens per Sec:    10397, Lr: 0.000613
# 2023-05-06 13:27:01,233 - INFO - joeynmt.training - Epoch   1, Step:     2700, Batch Loss:     3.152578, Tokens per Sec:    10325, Lr: 0.000601
# 2023-05-06 13:27:18,634 - INFO - joeynmt.training - Epoch   1, Step:     2800, Batch Loss:     3.228155, Tokens per Sec:    10457, Lr: 0.000591
# 2023-05-06 13:27:35,952 - INFO - joeynmt.training - Epoch   1, Step:     2900, Batch Loss:     3.155873, Tokens per Sec:    10429, Lr: 0.000580
# 2023-05-06 13:27:53,398 - INFO - joeynmt.training - Epoch   1, Step:     3000, Batch Loss:     3.019667, Tokens per Sec:    10375, Lr: 0.000571
# 2023-05-06 13:28:30,695 - WARNING - sacrebleu - That's 100 lines that end in a tokenized period ('.')
# 2023-05-06 13:28:30,695 - WARNING - sacrebleu - It looks like you forgot to detokenize your test data, which may hurt your score.
# 2023-05-06 13:28:30,695 - WARNING - sacrebleu - If you insist your data is detokenized, or don't care, you can suppress this message with the `force` parameter.
# 2023-05-06 13:28:30,708 - INFO - joeynmt.training - Hooray! New best validation result [ppl]!
# 2023-05-06 13:28:31,091 - INFO - joeynmt.training - Example #0
# 2023-05-06 13:28:31,092 - INFO - joeynmt.training - 	Source:     The regions need to be given room to invest in their infrastructure and people according to their own priorities .
# 2023-05-06 13:28:31,092 - INFO - joeynmt.training - 	Reference:  Les régions doivent avoir la possibilité d&apos; investir dans leur infrastructure et leurs citoyens en fonction des priorités qui leur sont propres .
# 2023-05-06 13:28:31,092 - INFO - joeynmt.training - 	Hypothesis: Les régions doivent être prises à leur utilisation de leurs produits et de leurs produits .
# 2023-05-06 13:28:31,092 - INFO - joeynmt.training - Example #1
# 2023-05-06 13:28:31,092 - INFO - joeynmt.training - 	Source:     I think we should have a rule that we should know at least two hours in advance who will take the floor in the one-minute speeches .
# 2023-05-06 13:28:31,092 - INFO - joeynmt.training - 	Reference:  Je pense qu&apos; il devrait y avoir une règle pour que nous sachions au moins deux heures à l&apos; avance qui s&apos; exprimera dans les interventions d&apos; une minute .
# 2023-05-06 13:28:31,092 - INFO - joeynmt.training - 	Hypothesis: Je pense que nous devons nous nous nous nous nous nous efforcer de nombreux deux deux parties qui ont été résolues ou de la révision de la révision de la révision de la révision .
# 2023-05-06 13:28:31,092 - INFO - joeynmt.training - Example #2
# 2023-05-06 13:28:31,092 - INFO - joeynmt.training - 	Source:     "The President allocated me two minutes and thirty seconds , and I would like to make full use of them ."
# 2023-05-06 13:28:31,092 - INFO - joeynmt.training - 	Reference:  Le président m ’ a accordé deux minutes et trente secondes et je voudrais les utiliser pleinement .
# 2023-05-06 13:28:31,092 - INFO - joeynmt.training - 	Hypothesis: "Le Président , les deux parties et les deux parties , je voudrais vous remercier , et je voudrais vous demander à la possibilité de se faire ."
# 2023-05-06 13:28:31,092 - INFO - joeynmt.training - Example #3
# 2023-05-06 13:28:31,092 - INFO - joeynmt.training - 	Source:     It is therefore right to recommend that greater regulation be imposed on European football and that this should be connected with European law and the dynamics of the internal market .
# 2023-05-06 13:28:31,092 - INFO - joeynmt.training - 	Reference:  Il est donc normal de recommander que des réglementations plus strictes soient imposées au football européen et que celles-ci soient liées par la législation européenne et la dynamique du marché intérieur .
# 2023-05-06 13:28:31,092 - INFO - joeynmt.training - 	Hypothesis: Il est donc donc important que le règlement européen doit être plus plus efficace et que les travaux doivent être résolues et que le marché européen .
# 2023-05-06 13:28:31,092 - INFO - joeynmt.training - Validation result (greedy) at epoch   1, step     3000: bleu:   6.71, loss: 125223.3750, ppl:  18.7770, duration: 37.6942s
# 2023-05-06 13:28:48,375 - INFO - joeynmt.training - Epoch   1, Step:     3100, Batch Loss:     3.147983, Tokens per Sec:    10315, Lr: 0.000561
# 2023-05-06 13:29:05,767 - INFO - joeynmt.training - Epoch   1, Step:     3200, Batch Loss:     3.014123, Tokens per Sec:    10486, Lr: 0.000552
# 2023-05-06 13:29:23,154 - INFO - joeynmt.training - Epoch   1, Step:     3300, Batch Loss:     3.050048, Tokens per Sec:    10384, Lr: 0.000544
# 2023-05-06 13:29:40,567 - INFO - joeynmt.training - Epoch   1, Step:     3400, Batch Loss:     2.955482, Tokens per Sec:    10448, Lr: 0.000536
# 2023-05-06 13:29:58,040 - INFO - joeynmt.training - Epoch   1, Step:     3500, Batch Loss:     3.068216, Tokens per Sec:    10303, Lr: 0.000528
# 2023-05-06 13:30:15,485 - INFO - joeynmt.training - Epoch   1, Step:     3600, Batch Loss:     3.017987, Tokens per Sec:    10505, Lr: 0.000521
# 2023-05-06 13:30:32,957 - INFO - joeynmt.training - Epoch   1, Step:     3700, Batch Loss:     2.921851, Tokens per Sec:    10254, Lr: 0.000514
# 2023-05-06 13:30:50,353 - INFO - joeynmt.training - Epoch   1, Step:     3800, Batch Loss:     2.935989, Tokens per Sec:    10383, Lr: 0.000507
# 2023-05-06 13:31:07,586 - INFO - joeynmt.training - Epoch   1, Step:     3900, Batch Loss:     2.918588, Tokens per Sec:    10300, Lr: 0.000500
# 2023-05-06 13:31:25,031 - INFO - joeynmt.training - Epoch   1, Step:     4000, Batch Loss:     2.913893, Tokens per Sec:    10385, Lr: 0.000494
# 2023-05-06 13:32:07,318 - WARNING - sacrebleu - That's 100 lines that end in a tokenized period ('.')
# 2023-05-06 13:32:07,319 - WARNING - sacrebleu - It looks like you forgot to detokenize your test data, which may hurt your score.
# 2023-05-06 13:32:07,319 - WARNING - sacrebleu - If you insist your data is detokenized, or don't care, you can suppress this message with the `force` parameter.
# 2023-05-06 13:32:07,335 - INFO - joeynmt.training - Hooray! New best validation result [ppl]!
# 2023-05-06 13:32:07,695 - INFO - joeynmt.helpers - delete models/enfr_transformer/1000.ckpt
# 2023-05-06 13:32:07,728 - INFO - joeynmt.training - Example #0
# 2023-05-06 13:32:07,729 - INFO - joeynmt.training - 	Source:     The regions need to be given room to invest in their infrastructure and people according to their own priorities .
# 2023-05-06 13:32:07,729 - INFO - joeynmt.training - 	Reference:  Les régions doivent avoir la possibilité d&apos; investir dans leur infrastructure et leurs citoyens en fonction des priorités qui leur sont propres .
# 2023-05-06 13:32:07,729 - INFO - joeynmt.training - 	Hypothesis: Les régions doivent être prises en faveur de l&apos; infrastructure et de leur infrastructure et de leur utilisation de leurs priorités .
# 2023-05-06 13:32:07,729 - INFO - joeynmt.training - Example #1
# 2023-05-06 13:32:07,729 - INFO - joeynmt.training - 	Source:     I think we should have a rule that we should know at least two hours in advance who will take the floor in the one-minute speeches .
# 2023-05-06 13:32:07,729 - INFO - joeynmt.training - 	Reference:  Je pense qu&apos; il devrait y avoir une règle pour que nous sachions au moins deux heures à l&apos; avance qui s&apos; exprimera dans les interventions d&apos; une minute .
# 2023-05-06 13:32:07,729 - INFO - joeynmt.training - 	Hypothesis: Je pense que nous devrions faire face à deux parties que nous devrions faire face à deux reprises dans le monde .
# 2023-05-06 13:32:07,729 - INFO - joeynmt.training - Example #2
# 2023-05-06 13:32:07,729 - INFO - joeynmt.training - 	Source:     "The President allocated me two minutes and thirty seconds , and I would like to make full use of them ."
# 2023-05-06 13:32:07,729 - INFO - joeynmt.training - 	Reference:  Le président m ’ a accordé deux minutes et trente secondes et je voudrais les utiliser pleinement .
# 2023-05-06 13:32:07,729 - INFO - joeynmt.training - 	Hypothesis: "Le président de la présidence a été déposée et je voudrais vous dire , et je voudrais vous demander à l&apos; utilisation de l&apos; utilisation de l&apos; utilisation de l&apos; utilisation de l&apos; utilisation de l&apos; utilisation ."
# 2023-05-06 13:32:07,730 - INFO - joeynmt.training - Example #3
# 2023-05-06 13:32:07,730 - INFO - joeynmt.training - 	Source:     It is therefore right to recommend that greater regulation be imposed on European football and that this should be connected with European law and the dynamics of the internal market .
# 2023-05-06 13:32:07,730 - INFO - joeynmt.training - 	Reference:  Il est donc normal de recommander que des réglementations plus strictes soient imposées au football européen et que celles-ci soient liées par la législation européenne et la dynamique du marché intérieur .
# 2023-05-06 13:32:07,730 - INFO - joeynmt.training - 	Hypothesis: Il est donc nécessaire de faire que le règlement européen doit être plus en plus de plus de plus de plus de ce qui concerne le marché européen et le droit européen .
# 2023-05-06 13:32:07,730 - INFO - joeynmt.training - Validation result (greedy) at epoch   1, step     4000: bleu:   7.60, loss: 117516.9688, ppl:  15.6764, duration: 42.6982s
# 2023-05-06 13:32:25,170 - INFO - joeynmt.training - Epoch   1, Step:     4100, Batch Loss:     3.004295, Tokens per Sec:    10327, Lr: 0.000488
# 2023-05-06 13:32:42,523 - INFO - joeynmt.training - Epoch   1, Step:     4200, Batch Loss:     3.068353, Tokens per Sec:    10252, Lr: 0.000482
# 2023-05-06 13:32:59,994 - INFO - joeynmt.training - Epoch   1, Step:     4300, Batch Loss:     2.976579, Tokens per Sec:    10366, Lr: 0.000477
# 2023-05-06 13:33:17,330 - INFO - joeynmt.training - Epoch   1, Step:     4400, Batch Loss:     3.009976, Tokens per Sec:    10342, Lr: 0.000471
# 2023-05-06 13:33:34,737 - INFO - joeynmt.training - Epoch   1, Step:     4500, Batch Loss:     2.881735, Tokens per Sec:    10337, Lr: 0.000466
# 2023-05-06 13:33:52,277 - INFO - joeynmt.training - Epoch   1, Step:     4600, Batch Loss:     2.904634, Tokens per Sec:    10200, Lr: 0.000461
# 2023-05-06 13:34:09,594 - INFO - joeynmt.training - Epoch   1, Step:     4700, Batch Loss:     2.858287, Tokens per Sec:    10611, Lr: 0.000456
# 2023-05-06 13:34:27,057 - INFO - joeynmt.training - Epoch   1, Step:     4800, Batch Loss:     2.685168, Tokens per Sec:    10283, Lr: 0.000451
# 2023-05-06 13:34:44,537 - INFO - joeynmt.training - Epoch   1, Step:     4900, Batch Loss:     2.780647, Tokens per Sec:    10260, Lr: 0.000446
# 2023-05-06 13:35:01,901 - INFO - joeynmt.training - Epoch   1, Step:     5000, Batch Loss:     2.875115, Tokens per Sec:    10352, Lr: 0.000442
# 2023-05-06 13:35:42,477 - WARNING - sacrebleu - That's 100 lines that end in a tokenized period ('.')
# 2023-05-06 13:35:42,477 - WARNING - sacrebleu - It looks like you forgot to detokenize your test data, which may hurt your score.
# 2023-05-06 13:35:42,477 - WARNING - sacrebleu - If you insist your data is detokenized, or don't care, you can suppress this message with the `force` parameter.
# 2023-05-06 13:35:42,491 - INFO - joeynmt.training - Hooray! New best validation result [ppl]!
# 2023-05-06 13:35:42,867 - INFO - joeynmt.helpers - delete models/enfr_transformer/2000.ckpt
# 2023-05-06 13:35:42,898 - INFO - joeynmt.training - Example #0
# 2023-05-06 13:35:42,898 - INFO - joeynmt.training - 	Source:     The regions need to be given room to invest in their infrastructure and people according to their own priorities .
# 2023-05-06 13:35:42,899 - INFO - joeynmt.training - 	Reference:  Les régions doivent avoir la possibilité d&apos; investir dans leur infrastructure et leurs citoyens en fonction des priorités qui leur sont propres .
# 2023-05-06 13:35:42,899 - INFO - joeynmt.training - 	Hypothesis: Les régions doivent être prises par la réalisation de leurs infrastructures et de leurs propres personnes en vue de leur propre qualité .
# 2023-05-06 13:35:42,899 - INFO - joeynmt.training - Example #1
# 2023-05-06 13:35:42,899 - INFO - joeynmt.training - 	Source:     I think we should have a rule that we should know at least two hours in advance who will take the floor in the one-minute speeches .
# 2023-05-06 13:35:42,899 - INFO - joeynmt.training - 	Reference:  Je pense qu&apos; il devrait y avoir une règle pour que nous sachions au moins deux heures à l&apos; avance qui s&apos; exprimera dans les interventions d&apos; une minute .
# 2023-05-06 13:35:42,899 - INFO - joeynmt.training - 	Hypothesis: Je pense que nous devons faire un terme qui nous permettra de faire deux fois dans le monde où nous pourrons être résolues ou de la révision des délaissements .
# 2023-05-06 13:35:42,899 - INFO - joeynmt.training - Example #2
# 2023-05-06 13:35:42,899 - INFO - joeynmt.training - 	Source:     "The President allocated me two minutes and thirty seconds , and I would like to make full use of them ."
# 2023-05-06 13:35:42,899 - INFO - joeynmt.training - 	Reference:  Le président m ’ a accordé deux minutes et trente secondes et je voudrais les utiliser pleinement .
# 2023-05-06 13:35:42,899 - INFO - joeynmt.training - 	Hypothesis: "Le président de mon collègue , je voudrais commencer et à deux fois , et je voudrais vous demander à l&apos; utilisation de ces personnes ."
# 2023-05-06 13:35:42,899 - INFO - joeynmt.training - Example #3
# 2023-05-06 13:35:42,900 - INFO - joeynmt.training - 	Source:     It is therefore right to recommend that greater regulation be imposed on European football and that this should be connected with European law and the dynamics of the internal market .
# 2023-05-06 13:35:42,900 - INFO - joeynmt.training - 	Reference:  Il est donc normal de recommander que des réglementations plus strictes soient imposées au football européen et que celles-ci soient liées par la législation européenne et la dynamique du marché intérieur .
# 2023-05-06 13:35:42,900 - INFO - joeynmt.training - 	Hypothesis: Il est donc essentiel de mettre en œuvre le règlement européen et de la réalisation de tous les États membres doivent être prises en faveur du droit européen et de la pêche .
# 2023-05-06 13:35:42,900 - INFO - joeynmt.training - Validation result (greedy) at epoch   1, step     5000: bleu:   9.46, loss: 111279.7109, ppl:  13.5459, duration: 40.9984s
# 2023-05-06 13:36:00,462 - INFO - joeynmt.training - Epoch   1, Step:     5100, Batch Loss:     2.708933, Tokens per Sec:    10353, Lr: 0.000438
# 2023-05-06 13:36:17,871 - INFO - joeynmt.training - Epoch   1, Step:     5200, Batch Loss:     2.808825, Tokens per Sec:    10264, Lr: 0.000433
# 2023-05-06 13:36:35,136 - INFO - joeynmt.training - Epoch   1, Step:     5300, Batch Loss:     2.726850, Tokens per Sec:    10376, Lr: 0.000429
# 2023-05-06 13:36:52,552 - INFO - joeynmt.training - Epoch   1, Step:     5400, Batch Loss:     2.658983, Tokens per Sec:    10513, Lr: 0.000425
# 2023-05-06 13:37:10,052 - INFO - joeynmt.training - Epoch   1, Step:     5500, Batch Loss:     2.781375, Tokens per Sec:    10222, Lr: 0.000421
# 2023-05-06 13:37:27,475 - INFO - joeynmt.training - Epoch   1, Step:     5600, Batch Loss:     2.649257, Tokens per Sec:    10228, Lr: 0.000418
# 2023-05-06 13:37:44,882 - INFO - joeynmt.training - Epoch   1, Step:     5700, Batch Loss:     2.617027, Tokens per Sec:    10231, Lr: 0.000414
# 2023-05-06 13:38:02,287 - INFO - joeynmt.training - Epoch   1, Step:     5800, Batch Loss:     2.776409, Tokens per Sec:    10390, Lr: 0.000410
# 2023-05-06 13:38:19,757 - INFO - joeynmt.training - Epoch   1, Step:     5900, Batch Loss:     2.717604, Tokens per Sec:    10196, Lr: 0.000407
# 2023-05-06 13:38:37,055 - INFO - joeynmt.training - Epoch   1, Step:     6000, Batch Loss:     2.709187, Tokens per Sec:    10294, Lr: 0.000403
# 2023-05-06 13:39:20,953 - WARNING - sacrebleu - That's 100 lines that end in a tokenized period ('.')
# 2023-05-06 13:39:20,954 - WARNING - sacrebleu - It looks like you forgot to detokenize your test data, which may hurt your score.
# 2023-05-06 13:39:20,954 - WARNING - sacrebleu - If you insist your data is detokenized, or don't care, you can suppress this message with the `force` parameter.
# 2023-05-06 13:39:20,967 - INFO - joeynmt.training - Hooray! New best validation result [ppl]!
# 2023-05-06 13:39:21,311 - INFO - joeynmt.helpers - delete models/enfr_transformer/3000.ckpt
# 2023-05-06 13:39:21,340 - INFO - joeynmt.training - Example #0
# 2023-05-06 13:39:21,340 - INFO - joeynmt.training - 	Source:     The regions need to be given room to invest in their infrastructure and people according to their own priorities .
# 2023-05-06 13:39:21,341 - INFO - joeynmt.training - 	Reference:  Les régions doivent avoir la possibilité d&apos; investir dans leur infrastructure et leurs citoyens en fonction des priorités qui leur sont propres .
# 2023-05-06 13:39:21,341 - INFO - joeynmt.training - 	Hypothesis: Les régions doivent être résolus pour les infrastructures et les enfants en vue de leur propre propre propre propre propre propre propre .
# 2023-05-06 13:39:21,341 - INFO - joeynmt.training - Example #1
# 2023-05-06 13:39:21,341 - INFO - joeynmt.training - 	Source:     I think we should have a rule that we should know at least two hours in advance who will take the floor in the one-minute speeches .
# 2023-05-06 13:39:21,341 - INFO - joeynmt.training - 	Reference:  Je pense qu&apos; il devrait y avoir une règle pour que nous sachions au moins deux heures à l&apos; avance qui s&apos; exprimera dans les interventions d&apos; une minute .
# 2023-05-06 13:39:21,341 - INFO - joeynmt.training - 	Hypothesis: Je pense que nous devons faire preuve de la traite que nous ne pouvons pas faire deux fois dans les deux parties qui seront désormais de la réunion de la délégation de deux semaines .
# 2023-05-06 13:39:21,341 - INFO - joeynmt.training - Example #2
# 2023-05-06 13:39:21,341 - INFO - joeynmt.training - 	Source:     "The President allocated me two minutes and thirty seconds , and I would like to make full use of them ."
# 2023-05-06 13:39:21,342 - INFO - joeynmt.training - 	Reference:  Le président m ’ a accordé deux minutes et trente secondes et je voudrais les utiliser pleinement .
# 2023-05-06 13:39:21,342 - INFO - joeynmt.training - 	Hypothesis: "Le président de la dernière dernière minute et deux dernières années , je voudrais souligner que je voudrais vous assurer que les informations soient utilisées ."
# 2023-05-06 13:39:21,342 - INFO - joeynmt.training - Example #3
# 2023-05-06 13:39:21,342 - INFO - joeynmt.training - 	Source:     It is therefore right to recommend that greater regulation be imposed on European football and that this should be connected with European law and the dynamics of the internal market .
# 2023-05-06 13:39:21,342 - INFO - joeynmt.training - 	Reference:  Il est donc normal de recommander que des réglementations plus strictes soient imposées au football européen et que celles-ci soient liées par la législation européenne et la dynamique du marché intérieur .
# 2023-05-06 13:39:21,342 - INFO - joeynmt.training - 	Hypothesis: Il est donc indispensable que le règlement soit plus élevé dans le cadre de la législation européenne et que ce soit le droit européen et le marché intérieur .
# 2023-05-06 13:39:21,342 - INFO - joeynmt.training - Validation result (greedy) at epoch   1, step     6000: bleu:  10.87, loss: 106292.1328, ppl:  12.0526, duration: 44.2864s
# 2023-05-06 13:39:38,816 - INFO - joeynmt.training - Epoch   1, Step:     6100, Batch Loss:     2.761661, Tokens per Sec:    10291, Lr: 0.000400
# 2023-05-06 13:39:56,267 - INFO - joeynmt.training - Epoch   1, Step:     6200, Batch Loss:     2.676029, Tokens per Sec:    10555, Lr: 0.000397
# 2023-05-06 13:40:13,692 - INFO - joeynmt.training - Epoch   1, Step:     6300, Batch Loss:     2.658104, Tokens per Sec:    10297, Lr: 0.000394
# 2023-05-06 13:40:31,142 - INFO - joeynmt.training - Epoch   1, Step:     6400, Batch Loss:     2.494622, Tokens per Sec:    10466, Lr: 0.000391
# 2023-05-06 13:40:48,595 - INFO - joeynmt.training - Epoch   1, Step:     6500, Batch Loss:     2.538192, Tokens per Sec:    10336, Lr: 0.000388
# 2023-05-06 13:41:05,996 - INFO - joeynmt.training - Epoch   1, Step:     6600, Batch Loss:     2.578919, Tokens per Sec:    10528, Lr: 0.000385
# 2023-05-06 13:41:23,414 - INFO - joeynmt.training - Epoch   1, Step:     6700, Batch Loss:     2.465557, Tokens per Sec:    10386, Lr: 0.000382
# 2023-05-06 13:41:40,751 - INFO - joeynmt.training - Epoch   1, Step:     6800, Batch Loss:     2.552404, Tokens per Sec:    10382, Lr: 0.000379
# 2023-05-06 13:41:58,229 - INFO - joeynmt.training - Epoch   1, Step:     6900, Batch Loss:     2.534895, Tokens per Sec:    10435, Lr: 0.000376
# 2023-05-06 13:42:15,601 - INFO - joeynmt.training - Epoch   1, Step:     7000, Batch Loss:     2.799931, Tokens per Sec:    10512, Lr: 0.000374
# 2023-05-06 13:42:56,253 - WARNING - sacrebleu - That's 100 lines that end in a tokenized period ('.')
# 2023-05-06 13:42:56,253 - WARNING - sacrebleu - It looks like you forgot to detokenize your test data, which may hurt your score.
# 2023-05-06 13:42:56,253 - WARNING - sacrebleu - If you insist your data is detokenized, or don't care, you can suppress this message with the `force` parameter.
# 2023-05-06 13:42:56,267 - INFO - joeynmt.training - Hooray! New best validation result [ppl]!
# 2023-05-06 13:42:56,624 - INFO - joeynmt.helpers - delete models/enfr_transformer/4000.ckpt
# 2023-05-06 13:42:56,657 - INFO - joeynmt.training - Example #0
# 2023-05-06 13:42:56,657 - INFO - joeynmt.training - 	Source:     The regions need to be given room to invest in their infrastructure and people according to their own priorities .
# 2023-05-06 13:42:56,657 - INFO - joeynmt.training - 	Reference:  Les régions doivent avoir la possibilité d&apos; investir dans leur infrastructure et leurs citoyens en fonction des priorités qui leur sont propres .
# 2023-05-06 13:42:56,658 - INFO - joeynmt.training - 	Hypothesis: Les régions doivent être résolus à l&apos; infrastructure et à leur propre propre propre propre propre propre propre propre propre propre propre propre propre .
# 2023-05-06 13:42:56,658 - INFO - joeynmt.training - Example #1
# 2023-05-06 13:42:56,658 - INFO - joeynmt.training - 	Source:     I think we should have a rule that we should know at least two hours in advance who will take the floor in the one-minute speeches .
# 2023-05-06 13:42:56,658 - INFO - joeynmt.training - 	Reference:  Je pense qu&apos; il devrait y avoir une règle pour que nous sachions au moins deux heures à l&apos; avance qui s&apos; exprimera dans les interventions d&apos; une minute .
# 2023-05-06 13:42:56,658 - INFO - joeynmt.training - 	Hypothesis: Je pense que nous devons faire un mot qui nous occupe à deux heures qui seront réussi à la suite de la décharge ou de délégation .
# 2023-05-06 13:42:56,658 - INFO - joeynmt.training - Example #2
# 2023-05-06 13:42:56,658 - INFO - joeynmt.training - 	Source:     "The President allocated me two minutes and thirty seconds , and I would like to make full use of them ."
# 2023-05-06 13:42:56,658 - INFO - joeynmt.training - 	Reference:  Le président m ’ a accordé deux minutes et trente secondes et je voudrais les utiliser pleinement .
# 2023-05-06 13:42:56,658 - INFO - joeynmt.training - 	Hypothesis: "Le président de la Commission a déposé deux minutes et je voudrais faire face à l&apos; utilisation de ces deux parties ."
# 2023-05-06 13:42:56,658 - INFO - joeynmt.training - Example #3
# 2023-05-06 13:42:56,658 - INFO - joeynmt.training - 	Source:     It is therefore right to recommend that greater regulation be imposed on European football and that this should be connected with European law and the dynamics of the internal market .
# 2023-05-06 13:42:56,658 - INFO - joeynmt.training - 	Reference:  Il est donc normal de recommander que des réglementations plus strictes soient imposées au football européen et que celles-ci soient liées par la législation européenne et la dynamique du marché intérieur .
# 2023-05-06 13:42:56,659 - INFO - joeynmt.training - 	Hypothesis: Il est donc donc possible de mettre en œuvre un règlement plus élevé sur le système européen et que tous les États membres doivent être respectées et le marché intérieur .
# 2023-05-06 13:42:56,659 - INFO - joeynmt.training - Validation result (greedy) at epoch   1, step     7000: bleu:  12.52, loss: 102204.8438, ppl:  10.9524, duration: 41.0573s
# 2023-05-06 13:43:14,174 - INFO - joeynmt.training - Epoch   1, Step:     7100, Batch Loss:     2.652921, Tokens per Sec:    10379, Lr: 0.000371
# 2023-05-06 13:43:31,549 - INFO - joeynmt.training - Epoch   1, Step:     7200, Batch Loss:     2.469333, Tokens per Sec:    10400, Lr: 0.000368
# 2023-05-06 13:43:48,953 - INFO - joeynmt.training - Epoch   1, Step:     7300, Batch Loss:     2.572096, Tokens per Sec:    10529, Lr: 0.000366
# 2023-05-06 13:44:06,365 - INFO - joeynmt.training - Epoch   1, Step:     7400, Batch Loss:     2.509037, Tokens per Sec:    10399, Lr: 0.000363
# 2023-05-06 13:44:23,849 - INFO - joeynmt.training - Epoch   1, Step:     7500, Batch Loss:     2.475437, Tokens per Sec:    10404, Lr: 0.000361
# 2023-05-06 13:44:41,294 - INFO - joeynmt.training - Epoch   1, Step:     7600, Batch Loss:     2.607629, Tokens per Sec:    10440, Lr: 0.000358
# 2023-05-06 13:44:58,603 - INFO - joeynmt.training - Epoch   1, Step:     7700, Batch Loss:     2.609592, Tokens per Sec:    10508, Lr: 0.000356
# 2023-05-06 13:45:16,011 - INFO - joeynmt.training - Epoch   1, Step:     7800, Batch Loss:     2.409093, Tokens per Sec:    10375, Lr: 0.000354
# 2023-05-06 13:45:33,419 - INFO - joeynmt.training - Epoch   1, Step:     7900, Batch Loss:     2.454003, Tokens per Sec:    10477, Lr: 0.000352
# 2023-05-06 13:45:50,869 - INFO - joeynmt.training - Epoch   1, Step:     8000, Batch Loss:     2.608833, Tokens per Sec:    10379, Lr: 0.000349
# 2023-05-06 13:46:32,350 - WARNING - sacrebleu - That's 100 lines that end in a tokenized period ('.')
# 2023-05-06 13:46:32,350 - WARNING - sacrebleu - It looks like you forgot to detokenize your test data, which may hurt your score.
# 2023-05-06 13:46:32,350 - WARNING - sacrebleu - If you insist your data is detokenized, or don't care, you can suppress this message with the `force` parameter.
# 2023-05-06 13:46:32,364 - INFO - joeynmt.training - Hooray! New best validation result [ppl]!
# 2023-05-06 13:46:32,710 - INFO - joeynmt.helpers - delete models/enfr_transformer/5000.ckpt
# 2023-05-06 13:46:32,736 - INFO - joeynmt.training - Example #0
# 2023-05-06 13:46:32,736 - INFO - joeynmt.training - 	Source:     The regions need to be given room to invest in their infrastructure and people according to their own priorities .
# 2023-05-06 13:46:32,736 - INFO - joeynmt.training - 	Reference:  Les régions doivent avoir la possibilité d&apos; investir dans leur infrastructure et leurs citoyens en fonction des priorités qui leur sont propres .
# 2023-05-06 13:46:32,736 - INFO - joeynmt.training - 	Hypothesis: Les régions doivent être résolus à l&apos; instar de leurs infrastructures et de leur propre propre population .
# 2023-05-06 13:46:32,736 - INFO - joeynmt.training - Example #1
# 2023-05-06 13:46:32,737 - INFO - joeynmt.training - 	Source:     I think we should have a rule that we should know at least two hours in advance who will take the floor in the one-minute speeches .
# 2023-05-06 13:46:32,737 - INFO - joeynmt.training - 	Reference:  Je pense qu&apos; il devrait y avoir une règle pour que nous sachions au moins deux heures à l&apos; avance qui s&apos; exprimera dans les interventions d&apos; une minute .
# 2023-05-06 13:46:32,737 - INFO - joeynmt.training - 	Hypothesis: Je pense que nous devons faire un moteur qui nous occupe à deux heures qui seront résolus ou à la fin de la décharge des délais .
# 2023-05-06 13:46:32,737 - INFO - joeynmt.training - Example #2
# 2023-05-06 13:46:32,737 - INFO - joeynmt.training - 	Source:     "The President allocated me two minutes and thirty seconds , and I would like to make full use of them ."
# 2023-05-06 13:46:32,737 - INFO - joeynmt.training - 	Reference:  Le président m ’ a accordé deux minutes et trente secondes et je voudrais les utiliser pleinement .
# 2023-05-06 13:46:32,737 - INFO - joeynmt.training - 	Hypothesis: "Le président de la Commission a déposé deux minutes et les deux tiers , et je voudrais faire preuve de manière très efficace ."
# 2023-05-06 13:46:32,737 - INFO - joeynmt.training - Example #3
# ...
# 2023-05-06 15:41:29,514 - INFO - joeynmt.training - 	Hypothesis: Les régions doivent être accordées à l&apos; invitation dans leur infrastructure et les personnes conformément à leurs propres priorités .
# 2023-05-06 15:41:29,514 - INFO - joeynmt.training - Example #1
# 2023-05-06 15:41:29,514 - INFO - joeynmt.training - 	Source:     I think we should have a rule that we should know at least two hours in advance who will take the floor in the one-minute speeches .
# 2023-05-06 15:41:29,514 - INFO - joeynmt.training - 	Reference:  Je pense qu&apos; il devrait y avoir une règle pour que nous sachions au moins deux heures à l&apos; avance qui s&apos; exprimera dans les interventions d&apos; une minute .
# 2023-05-06 15:41:29,514 - INFO - joeynmt.training - 	Hypothesis: Je pense que nous devrions avoir une règle que nous devrions savoir au moins deux heures dans l&apos; avancement qui prendra la parole dans les interventions de minute .
# 2023-05-06 15:41:29,514 - INFO - joeynmt.training - Example #2
# 2023-05-06 15:41:29,514 - INFO - joeynmt.training - 	Source:     "The President allocated me two minutes and thirty seconds , and I would like to make full use of them ."
# 2023-05-06 15:41:29,514 - INFO - joeynmt.training - 	Reference:  Le président m ’ a accordé deux minutes et trente secondes et je voudrais les utiliser pleinement .
# 2023-05-06 15:41:29,514 - INFO - joeynmt.training - 	Hypothesis: "Le président m&apos; a délocalisé deux minutes et deux secondes , et je voudrais faire tout son utilisation ."
# 2023-05-06 15:41:29,514 - INFO - joeynmt.training - Example #3
# 2023-05-06 15:41:29,515 - INFO - joeynmt.training - 	Source:     It is therefore right to recommend that greater regulation be imposed on European football and that this should be connected with European law and the dynamics of the internal market .
# 2023-05-06 15:41:29,515 - INFO - joeynmt.training - 	Reference:  Il est donc normal de recommander que des réglementations plus strictes soient imposées au football européen et que celles-ci soient liées par la législation européenne et la dynamique du marché intérieur .
# 2023-05-06 15:41:29,515 - INFO - joeynmt.training - 	Hypothesis: Il est donc juste de recommander que le règlement plus important soit imposé sur le football européen et que cela devrait être lié à la loi européenne et aux dynamiques du marché intérieur .
# 2023-05-06 15:41:29,515 - INFO - joeynmt.training - Validation result (greedy) at epoch   1, step    40000: bleu:  26.27, loss: 67916.8906, ppl:   4.9065, duration: 41.7537s
# 2023-05-06 15:41:46,964 - INFO - joeynmt.training - Epoch   1, Step:    40100, Batch Loss:     1.855218, Tokens per Sec:    10324, Lr: 0.000156
# 2023-05-06 15:42:04,358 - INFO - joeynmt.training - Epoch   1, Step:    40200, Batch Loss:     1.637659, Tokens per Sec:    10504, Lr: 0.000156
# 2023-05-06 15:42:21,709 - INFO - joeynmt.training - Epoch   1, Step:    40300, Batch Loss:     1.761133, Tokens per Sec:    10278, Lr: 0.000156
# 2023-05-06 15:42:39,007 - INFO - joeynmt.training - Epoch   1, Step:    40400, Batch Loss:     1.761174, Tokens per Sec:    10385, Lr: 0.000155
# 2023-05-06 15:42:56,416 - INFO - joeynmt.training - Epoch   1, Step:    40500, Batch Loss:     1.704292, Tokens per Sec:    10412, Lr: 0.000155
# 2023-05-06 15:43:13,894 - INFO - joeynmt.training - Epoch   1, Step:    40600, Batch Loss:     1.864483, Tokens per Sec:    10460, Lr: 0.000155
# 2023-05-06 15:43:31,151 - INFO - joeynmt.training - Epoch   1, Step:    40700, Batch Loss:     1.911726, Tokens per Sec:    10425, Lr: 0.000155
# 2023-05-06 15:43:48,555 - INFO - joeynmt.training - Epoch   1, Step:    40800, Batch Loss:     1.967731, Tokens per Sec:    10454, Lr: 0.000155
# 2023-05-06 15:44:05,938 - INFO - joeynmt.training - Epoch   1, Step:    40900, Batch Loss:     1.739538, Tokens per Sec:    10542, Lr: 0.000155
# 2023-05-06 15:44:23,401 - INFO - joeynmt.training - Epoch   1, Step:    41000, Batch Loss:     1.736793, Tokens per Sec:    10372, Lr: 0.000154
# 2023-05-06 15:45:05,709 - WARNING - sacrebleu - That's 100 lines that end in a tokenized period ('.')
# 2023-05-06 15:45:05,709 - WARNING - sacrebleu - It looks like you forgot to detokenize your test data, which may hurt your score.
# 2023-05-06 15:45:05,709 - WARNING - sacrebleu - If you insist your data is detokenized, or don't care, you can suppress this message with the `force` parameter.
# 2023-05-06 15:45:05,723 - INFO - joeynmt.training - Hooray! New best validation result [ppl]!
# 2023-05-06 15:45:06,071 - INFO - joeynmt.helpers - delete models/enfr_transformer/38000.ckpt
# 2023-05-06 15:45:06,099 - INFO - joeynmt.training - Example #0
# 2023-05-06 15:45:06,099 - INFO - joeynmt.training - 	Source:     The regions need to be given room to invest in their infrastructure and people according to their own priorities .
# 2023-05-06 15:45:06,099 - INFO - joeynmt.training - 	Reference:  Les régions doivent avoir la possibilité d&apos; investir dans leur infrastructure et leurs citoyens en fonction des priorités qui leur sont propres .
# 2023-05-06 15:45:06,099 - INFO - joeynmt.training - 	Hypothesis: Les régions doivent être accordées à l&apos; invitation dans leur infrastructure et aux personnes conformément à leurs propres priorités .
# 2023-05-06 15:45:06,099 - INFO - joeynmt.training - Example #1
# 2023-05-06 15:45:06,100 - INFO - joeynmt.training - 	Source:     I think we should have a rule that we should know at least two hours in advance who will take the floor in the one-minute speeches .
# 2023-05-06 15:45:06,100 - INFO - joeynmt.training - 	Reference:  Je pense qu&apos; il devrait y avoir une règle pour que nous sachions au moins deux heures à l&apos; avance qui s&apos; exprimera dans les interventions d&apos; une minute .
# 2023-05-06 15:45:06,100 - INFO - joeynmt.training - 	Hypothesis: Je pense que nous devons avoir une règle que nous devrions savoir au moins deux heures qui prendront la parole dans les interventions de minute .
# 2023-05-06 15:45:06,100 - INFO - joeynmt.training - Example #2
# 2023-05-06 15:45:06,100 - INFO - joeynmt.training - 	Source:     "The President allocated me two minutes and thirty seconds , and I would like to make full use of them ."
# 2023-05-06 15:45:06,100 - INFO - joeynmt.training - 	Reference:  Le président m ’ a accordé deux minutes et trente secondes et je voudrais les utiliser pleinement .
# 2023-05-06 15:45:06,100 - INFO - joeynmt.training - 	Hypothesis: "Le président m&apos; a alloué deux minutes et deux secondes , et je voudrais faire pleinement l&apos; utilisation de ces deux minutes ."
# 2023-05-06 15:45:06,100 - INFO - joeynmt.training - Example #3
# 2023-05-06 15:45:06,100 - INFO - joeynmt.training - 	Source:     It is therefore right to recommend that greater regulation be imposed on European football and that this should be connected with European law and the dynamics of the internal market .
# 2023-05-06 15:45:06,100 - INFO - joeynmt.training - 	Reference:  Il est donc normal de recommander que des réglementations plus strictes soient imposées au football européen et que celles-ci soient liées par la législation européenne et la dynamique du marché intérieur .
# 2023-05-06 15:45:06,100 - INFO - joeynmt.training - 	Hypothesis: Il est donc juste de recommander que la réglementation plus importante soit imposée sur la football européenne et que cela devrait être liée à la loi européenne et à la dynamique du marché intérieur .
# 2023-05-06 15:45:06,101 - INFO - joeynmt.training - Validation result (greedy) at epoch   1, step    41000: bleu:  26.53, loss: 67428.6641, ppl:   4.8507, duration: 42.6990s
# 2023-05-06 15:45:23,538 - INFO - joeynmt.training - Epoch   1, Step:    41100, Batch Loss:     1.807591, Tokens per Sec:    10477, Lr: 0.000154
# 2023-05-06 15:45:40,897 - INFO - joeynmt.training - Epoch   1, Step:    41200, Batch Loss:     1.776961, Tokens per Sec:    10565, Lr: 0.000154
# 2023-05-06 15:45:58,297 - INFO - joeynmt.training - Epoch   1, Step:    41300, Batch Loss:     1.850847, Tokens per Sec:    10352, Lr: 0.000154
# 2023-05-06 15:46:15,581 - INFO - joeynmt.training - Epoch   1, Step:    41400, Batch Loss:     1.737053, Tokens per Sec:    10448, Lr: 0.000154
# 2023-05-06 15:46:32,989 - INFO - joeynmt.training - Epoch   1, Step:    41500, Batch Loss:     1.801262, Tokens per Sec:    10295, Lr: 0.000153
# 2023-05-06 15:46:50,313 - INFO - joeynmt.training - Epoch   1, Step:    41600, Batch Loss:     1.829409, Tokens per Sec:    10451, Lr: 0.000153
# 2023-05-06 15:47:07,687 - INFO - joeynmt.training - Epoch   1, Step:    41700, Batch Loss:     1.774451, Tokens per Sec:    10536, Lr: 0.000153
# 2023-05-06 15:47:25,164 - INFO - joeynmt.training - Epoch   1, Step:    41800, Batch Loss:     1.783263, Tokens per Sec:    10493, Lr: 0.000153
# 2023-05-06 15:47:42,719 - INFO - joeynmt.training - Epoch   1, Step:    41900, Batch Loss:     1.677649, Tokens per Sec:    10209, Lr: 0.000153
# 2023-05-06 15:48:00,225 - INFO - joeynmt.training - Epoch   1, Step:    42000, Batch Loss:     1.631932, Tokens per Sec:    10364, Lr: 0.000152
# 2023-05-06 15:48:42,252 - WARNING - sacrebleu - That's 100 lines that end in a tokenized period ('.')
# 2023-05-06 15:48:42,252 - WARNING - sacrebleu - It looks like you forgot to detokenize your test data, which may hurt your score.
# 2023-05-06 15:48:42,252 - WARNING - sacrebleu - If you insist your data is detokenized, or don't care, you can suppress this message with the `force` parameter.
# 2023-05-06 15:48:42,269 - INFO - joeynmt.training - Hooray! New best validation result [ppl]!
# 2023-05-06 15:48:42,625 - INFO - joeynmt.helpers - delete models/enfr_transformer/39000.ckpt
# 2023-05-06 15:48:42,655 - INFO - joeynmt.training - Example #0
# 2023-05-06 15:48:42,656 - INFO - joeynmt.training - 	Source:     The regions need to be given room to invest in their infrastructure and people according to their own priorities .
# 2023-05-06 15:48:42,656 - INFO - joeynmt.training - 	Reference:  Les régions doivent avoir la possibilité d&apos; investir dans leur infrastructure et leurs citoyens en fonction des priorités qui leur sont propres .
# 2023-05-06 15:48:42,656 - INFO - joeynmt.training - 	Hypothesis: Les régions doivent être accordées à l&apos; invitation dans leur infrastructure et les personnes conformément à leurs propres priorités .
# 2023-05-06 15:48:42,656 - INFO - joeynmt.training - Example #1
# 2023-05-06 15:48:42,656 - INFO - joeynmt.training - 	Source:     I think we should have a rule that we should know at least two hours in advance who will take the floor in the one-minute speeches .
# 2023-05-06 15:48:42,656 - INFO - joeynmt.training - 	Reference:  Je pense qu&apos; il devrait y avoir une règle pour que nous sachions au moins deux heures à l&apos; avance qui s&apos; exprimera dans les interventions d&apos; une minute .
# 2023-05-06 15:48:42,656 - INFO - joeynmt.training - 	Hypothesis: Je pense que nous devons avoir une règle que nous devrions savoir au moins deux heures qui prendront la parole dans les interventions de minute .
# 2023-05-06 15:48:42,656 - INFO - joeynmt.training - Example #2
# 2023-05-06 15:48:42,656 - INFO - joeynmt.training - 	Source:     "The President allocated me two minutes and thirty seconds , and I would like to make full use of them ."
# 2023-05-06 15:48:42,656 - INFO - joeynmt.training - 	Reference:  Le président m ’ a accordé deux minutes et trente secondes et je voudrais les utiliser pleinement .
# 2023-05-06 15:48:42,656 - INFO - joeynmt.training - 	Hypothesis: "Le président m&apos; a alloué deux minutes et deux secondes , et je voudrais faire pleinement l&apos; utilisation de ces deux minutes ."
# 2023-05-06 15:48:42,657 - INFO - joeynmt.training - Example #3
# 2023-05-06 15:48:42,657 - INFO - joeynmt.training - 	Source:     It is therefore right to recommend that greater regulation be imposed on European football and that this should be connected with European law and the dynamics of the internal market .
# 2023-05-06 15:48:42,657 - INFO - joeynmt.training - 	Reference:  Il est donc normal de recommander que des réglementations plus strictes soient imposées au football européen et que celles-ci soient liées par la législation européenne et la dynamique du marché intérieur .
# 2023-05-06 15:48:42,657 - INFO - joeynmt.training - 	Hypothesis: Il est donc juste de recommander que la réglementation plus importante soit imposée sur le football européen et que cela devrait être liée au droit européen et aux dynamiques du marché intérieur .
# 2023-05-06 15:48:42,657 - INFO - joeynmt.training - Validation result (greedy) at epoch   1, step    42000: bleu:  26.68, loss: 67243.0859, ppl:   4.8297, duration: 42.4312s
# 2023-05-06 15:49:00,071 - INFO - joeynmt.training - Epoch   1, Step:    42100, Batch Loss:     1.794259, Tokens per Sec:    10484, Lr: 0.000152
# 2023-05-06 15:49:17,468 - INFO - joeynmt.training - Epoch   1, Step:    42200, Batch Loss:     1.821005, Tokens per Sec:    10353, Lr: 0.000152
# 2023-05-06 15:49:34,831 - INFO - joeynmt.training - Epoch   1, Step:    42300, Batch Loss:     1.735645, Tokens per Sec:    10541, Lr: 0.000152
# 2023-05-06 15:49:52,201 - INFO - joeynmt.training - Epoch   1, Step:    42400, Batch Loss:     1.680338, Tokens per Sec:    10292, Lr: 0.000152
# 2023-05-06 15:50:09,608 - INFO - joeynmt.training - Epoch   1, Step:    42500, Batch Loss:     1.826588, Tokens per Sec:    10405, Lr: 0.000152
# 2023-05-06 15:50:26,880 - INFO - joeynmt.training - Epoch   1, Step:    42600, Batch Loss:     1.830297, Tokens per Sec:    10355, Lr: 0.000151
# 2023-05-06 15:50:44,281 - INFO - joeynmt.training - Epoch   1, Step:    42700, Batch Loss:     1.783718, Tokens per Sec:    10373, Lr: 0.000151
# 2023-05-06 15:51:01,722 - INFO - joeynmt.training - Epoch   1, Step:    42800, Batch Loss:     1.798418, Tokens per Sec:    10331, Lr: 0.000151
# 2023-05-06 15:51:18,994 - INFO - joeynmt.training - Epoch   1: total training loss 95993.58
# 2023-05-06 15:51:18,995 - INFO - joeynmt.training - Training ended after   1 epochs.
# 2023-05-06 15:51:18,995 - INFO - joeynmt.training - Best validation result (greedy) at step    42000:   4.83 ppl.
# 2023-05-06 15:51:19,013 - INFO - joeynmt.prediction - Process device: cuda, n_gpu: 1, batch_size per device: 3600
# 2023-05-06 15:51:19,014 - INFO - joeynmt.prediction - Loading model from models/enfr_transformer/42000.ckpt
# 2023-05-06 15:51:19,198 - INFO - joeynmt.model - Building an encoder-decoder model...
# 2023-05-06 15:51:19,444 - INFO - joeynmt.model - Enc-dec model built.
# 2023-05-06 15:51:19,520 - INFO - joeynmt.prediction - Decoding on dev set (data/enfr/dev.bpe.fr)...
# 2023-05-06 15:52:25,852 - WARNING - sacrebleu - That's 100 lines that end in a tokenized period ('.')
# 2023-05-06 15:52:25,852 - WARNING - sacrebleu - It looks like you forgot to detokenize your test data, which may hurt your score.
# 2023-05-06 15:52:25,852 - WARNING - sacrebleu - If you insist your data is detokenized, or don't care, you can suppress this message with the `force` parameter.
# 2023-05-06 15:52:25,868 - INFO - joeynmt.prediction -  dev bleu[none]:  28.05 [Beam search decoding with beam size = 5 and alpha = {beam_alpha}]
# 2023-05-06 15:52:25,870 - INFO - joeynmt.prediction - Translations saved to: models/enfr_transformer/00042000.hyps.dev
# 2023-05-06 15:52:25,870 - INFO - joeynmt.prediction - Decoding on test set (data/enfr/test.bpe.fr)...
# 2023-05-06 15:52:52,958 - WARNING - sacrebleu - That's 100 lines that end in a tokenized period ('.')
# 2023-05-06 15:52:52,958 - WARNING - sacrebleu - It looks like you forgot to detokenize your test data, which may hurt your score.
# 2023-05-06 15:52:52,958 - WARNING - sacrebleu - If you insist your data is detokenized, or don't care, you can suppress this message with the `force` parameter.
# 2023-05-06 15:52:52,963 - INFO - joeynmt.prediction - test bleu[none]:   8.79 [Beam search decoding with beam size = 5 and alpha = {beam_alpha}]
# 2023-05-06 15:52:52,964 - INFO - joeynmt.prediction - Translations saved to: models/enfr_transformer/00042000.hyps.test

# %%
# Copy the created models from the notebook storage to google drive for persistent storage 
! mkdir -p "$gdrive_path/models/${src}${tgt}_transformer/"
! cp -r joeynmt/models/${src}${tgt}_transformer/* "$gdrive_path/models/${src}${tgt}_transformer/"

# %%
# Output our validation accuracy
! cat "$gdrive_path/models/${src}${tgt}_transformer/validations.txt"
# Out:
# Steps: 1000	Loss: 169931.17188	PPL: 53.49845	bleu: 1.64857	LR: 0.00098821	*
# Steps: 2000	Loss: 139320.68750	PPL: 26.12204	bleu: 4.10519	LR: 0.00069877	*
# Steps: 3000	Loss: 125223.37500	PPL: 18.77698	bleu: 6.70591	LR: 0.00057054	*
# Steps: 4000	Loss: 117516.96875	PPL: 15.67636	bleu: 7.59546	LR: 0.00049411	*
# Steps: 5000	Loss: 111279.71094	PPL: 13.54588	bleu: 9.46025	LR: 0.00044194	*
# Steps: 6000	Loss: 106292.13281	PPL: 12.05256	bleu: 10.87148	LR: 0.00040344	*
# Steps: 7000	Loss: 102204.84375	PPL: 10.95237	bleu: 12.51629	LR: 0.00037351	*
# Steps: 8000	Loss: 98163.17188	PPL: 9.96325	bleu: 13.75842	LR: 0.00034939	*
# Steps: 9000	Loss: 94783.03125	PPL: 9.20496	bleu: 14.87648	LR: 0.00032940	*
# Steps: 10000	Loss: 92127.85156	PPL: 8.65001	bleu: 15.92254	LR: 0.00031250	*
# Steps: 11000	Loss: 89756.49219	PPL: 8.18273	bleu: 16.88392	LR: 0.00029796	*
# Steps: 12000	Loss: 87553.21094	PPL: 7.77121	bleu: 17.76840	LR: 0.00028527	*
# Steps: 13000	Loss: 85942.00781	PPL: 7.48345	bleu: 18.57028	LR: 0.00027408	*
# Steps: 14000	Loss: 84268.41406	PPL: 7.19581	bleu: 19.15117	LR: 0.00026411	*
# Steps: 15000	Loss: 82922.94531	PPL: 6.97261	bleu: 20.02220	LR: 0.00025516	*
# Steps: 16000	Loss: 81544.82812	PPL: 6.75116	bleu: 20.32922	LR: 0.00024705	*
# Steps: 17000	Loss: 80458.38281	PPL: 6.58156	bleu: 20.72521	LR: 0.00023968	*
# Steps: 18000	Loss: 79516.89844	PPL: 6.43803	bleu: 21.18477	LR: 0.00023292	*
# Steps: 19000	Loss: 78499.46875	PPL: 6.28644	bleu: 21.64778	LR: 0.00022671	*
# Steps: 20000	Loss: 77386.64844	PPL: 6.12472	bleu: 21.85804	LR: 0.00022097	*
# Steps: 21000	Loss: 76807.46875	PPL: 6.04221	bleu: 22.51148	LR: 0.00021565	*
# Steps: 22000	Loss: 76145.17969	PPL: 5.94922	bleu: 22.95554	LR: 0.00021069	*
# Steps: 23000	Loss: 75192.80469	PPL: 5.81799	bleu: 23.15185	LR: 0.00020606	*
# Steps: 24000	Loss: 74500.85938	PPL: 5.72447	bleu: 23.35595	LR: 0.00020172	*
# Steps: 25000	Loss: 73941.32812	PPL: 5.64995	bleu: 23.92829	LR: 0.00019764	*
# Steps: 26000	Loss: 73357.07031	PPL: 5.57317	bleu: 23.93519	LR: 0.00019380	*
# Steps: 27000	Loss: 72744.07812	PPL: 5.49373	bleu: 24.30703	LR: 0.00019018	*
# Steps: 28000	Loss: 72335.39844	PPL: 5.44141	bleu: 24.39063	LR: 0.00018675	*
# Steps: 29000	Loss: 71807.44531	PPL: 5.37454	bleu: 24.63838	LR: 0.00018351	*
# Steps: 30000	Loss: 71349.60156	PPL: 5.31722	bleu: 25.04541	LR: 0.00018042	*
# Steps: 31000	Loss: 70822.04688	PPL: 5.25193	bleu: 24.91397	LR: 0.00017749	*
# Steps: 32000	Loss: 70471.11719	PPL: 5.20895	bleu: 25.50899	LR: 0.00017469	*
# Steps: 33000	Loss: 70180.03125	PPL: 5.17356	bleu: 25.49591	LR: 0.00017203	*
# Steps: 34000	Loss: 69634.72656	PPL: 5.10791	bleu: 25.83131	LR: 0.00016948	*
# Steps: 35000	Loss: 69584.68750	PPL: 5.10192	bleu: 25.49953	LR: 0.00016704	*
# Steps: 36000	Loss: 69206.48438	PPL: 5.05694	bleu: 26.18537	LR: 0.00016470	*
# Steps: 37000	Loss: 68697.71094	PPL: 4.99704	bleu: 26.21790	LR: 0.00016246	*
# Steps: 38000	Loss: 68383.40625	PPL: 4.96039	bleu: 26.30205	LR: 0.00016031	*
# Steps: 39000	Loss: 68107.87500	PPL: 4.92849	bleu: 26.48096	LR: 0.00015824	*
# Steps: 40000	Loss: 67916.89062	PPL: 4.90649	bleu: 26.26853	LR: 0.00015625	*
# Steps: 41000	Loss: 67428.66406	PPL: 4.85071	bleu: 26.53211	LR: 0.00015433	*
# Steps: 42000	Loss: 67243.08594	PPL: 4.82968	bleu: 26.68074	LR: 0.00015248	*

# %%
# Test our model
! cd joeynmt; python3 -m joeynmt test "$gdrive_path/models/${src}${tgt}_transformer/config.yaml"
# Out:
# 2023-05-06 15:55:53,061 - INFO - root - Hello! This is Joey-NMT (version 1.5).
# 2023-05-06 15:55:53,062 - INFO - joeynmt.data - Building vocabulary...
# 2023-05-06 15:55:53,305 - INFO - joeynmt.data - Loading dev data...
# 2023-05-06 15:55:53,326 - INFO - joeynmt.data - Loading test data...
# 2023-05-06 15:55:53,334 - INFO - joeynmt.data - Data loaded.
# 2023-05-06 15:55:53,366 - INFO - joeynmt.prediction - Process device: cuda, n_gpu: 1, batch_size per device: 3600
# 2023-05-06 15:55:53,367 - INFO - joeynmt.prediction - Loading model from models/enfr_transformer/42000.ckpt
# 2023-05-06 15:55:57,589 - INFO - joeynmt.model - Building an encoder-decoder model...
# 2023-05-06 15:55:57,824 - INFO - joeynmt.model - Enc-dec model built.
# 2023-05-06 15:55:57,893 - INFO - joeynmt.prediction - Decoding on dev set (data/enfr/dev.bpe.fr)...
# 2023-05-06 15:56:58,472 - WARNING - sacrebleu - That's 100 lines that end in a tokenized period ('.')
# 2023-05-06 15:56:58,472 - WARNING - sacrebleu - It looks like you forgot to detokenize your test data, which may hurt your score.
# 2023-05-06 15:56:58,472 - WARNING - sacrebleu - If you insist your data is detokenized, or don't care, you can suppress this message with the `force` parameter.
# 2023-05-06 15:56:58,479 - INFO - joeynmt.prediction -  dev bleu[none]:  28.05 [Beam search decoding with beam size = 5 and alpha = {beam_alpha}]
# 2023-05-06 15:56:58,479 - INFO - joeynmt.prediction - Decoding on test set (data/enfr/test.bpe.fr)...
# 2023-05-06 15:57:23,961 - WARNING - sacrebleu - That's 100 lines that end in a tokenized period ('.')
# 2023-05-06 15:57:23,961 - WARNING - sacrebleu - It looks like you forgot to detokenize your test data, which may hurt your score.
# 2023-05-06 15:57:23,961 - WARNING - sacrebleu - If you insist your data is detokenized, or don't care, you can suppress this message with the `force` parameter.
# 2023-05-06 15:57:23,964 - INFO - joeynmt.prediction - test bleu[none]:   8.79 [Beam search decoding with beam size = 5 and alpha = {beam_alpha}]

# %%
# Copy translations to Drive
# !cp joeynmt/models/enfr_transformer/00042000.hyps.test "gdrive_path"
# !cp joeynmt/models/enfr_transformer/00042000.hyps.dev "gdrive_path"
